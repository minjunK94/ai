# %% [markdown]
# **<font size='6' color='aqua'>ch3. 연관분석</font>**
# - pip install apyori

# %%
! pip install apyori
# Out:
# Collecting apyori
#   Downloading apyori-1.1.2.tar.gz (8.6 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Building wheels for collected packages: apyori
#   Building wheel for apyori (setup.py): started
#   Building wheel for apyori (setup.py): finished with status 'done'
#   Created wheel for apyori: filename=apyori-1.1.2-py3-none-any.whl size=5975 sha256=1893cc0ae523d81482b6981adc4a4a7096261891fa2ae267bced07fbbd216d4a
#   Stored in directory: c:\users\4545\appdata\local\pip\cache\wheels\84\45\a4\8ade6576f75410d8162c6da1de0aa9df56c16c711acab5a813
# Successfully built apyori
# Installing collected packages: apyori
# Successfully installed apyori-1.1.2

# %% [markdown]
# # 1. 연관분석 개요
# - 데이터들 사이에 자주 발생하는 속성을 찾고, 그 속성들 사이에 연관성이 어느 정도 있는지 분석하는 방법
# - 활용분야 : 상품진열, 사기보험적발, 신상품 카테고리 구성....
#
# ```
# {조건} -> {결과}
# 연관분석과 관련 지표
# 1. 지지도(support) : 전체 데이터 중에 조건결과 항목들의 포함된 거래 비율
#     (X, Y)의 항목수 / 전체 데이터수 ex.0.2
# 2. 신뢰도(confidence) : 조건이 발생했을 때, 결과가 동시에 일어날 확률
#     (X, Y)의 항목수 / 조건항목수 ex.0.5
# 3. 향상도(lift) : 우현히 발생한 규칙은 아닌지 확인
#     조건결과 지지도 / (조건지지도)*(결과지지도)
#     <1 : 음의 상관 관계
#     >1 : 양의 상관관계
#                            지지도        신뢰도          향상도
# {오렌지주스} -> {와인}     1/5(0.2)      1/2(0.5)      0.2/0.4*0.6 = 0.2/0.24 = 0.833
# ```

# %%
# %ls data\cf_basket.csv
# Out:
#  D 드라이브의 볼륨에는 이름이 없습니다.
#  볼륨 일련 번호: 149E-6D0A
#
#  D:\ai\source\10_자연어처리\data 디렉터리
#
# 2024-12-30  오전 09:03               119 cf_basket.csv
#                1개 파일                 119 바이트
#                0개 디렉터리  472,588,083,200 바이트 남음

# %% [markdown]
# # 2. 연관분석 구현

# %%
# 트랜젝션 데이터 가져오기
import csv
transaction = []
with open('data/cf_basket.csv', 'r', encoding='utf-8') as f:
    csvdata = csv.reader(f)
    for row in csvdata:
        transaction.append(row)
transaction
# Out:
# [['소주', '콜라', '와인'],
#  ['소주', '오렌지주스', '콜라'],
#  ['맥주', '콜라', '와인'],
#  ['소주', '콜라', '맥주'],
#  ['오렌지주스', '와인']]

# %%
from apyori import apriori
rules = apriori(transaction, min_support=0.15, min_confidence=0.1)
rules = list(rules)
len(rules)
# Out:
# 18

# %%
rules[15]
# items=frozenset({'와인', '콜라', '맥주'}), support=0.2 : 이 세트가 함께 나타날 확률
# items_base : 조건(lhs)
# items_add : 결과(rhs)
# Out:
# RelationRecord(items=frozenset({'콜라', '맥주', '와인'}), support=0.2, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'콜라', '맥주', '와인'}), confidence=0.2, lift=1.0), OrderedStatistic(items_base=frozenset({'맥주'}), items_add=frozenset({'콜라', '와인'}), confidence=0.5, lift=1.25), OrderedStatistic(items_base=frozenset({'와인'}), items_add=frozenset({'콜라', '맥주'}), confidence=0.33333333333333337, lift=0.8333333333333334), OrderedStatistic(items_base=frozenset({'콜라'}), items_add=frozenset({'맥주', '와인'}), confidence=0.25, lift=1.25), OrderedStatistic(items_base=frozenset({'맥주', '와인'}), items_add=frozenset({'콜라'}), confidence=1.0, lift=1.25), OrderedStatistic(items_base=frozenset({'콜라', '맥주'}), items_add=frozenset({'와인'}), confidence=0.5, lift=0.8333333333333334), OrderedStatistic(items_base=frozenset({'콜라', '와인'}), items_add=frozenset({'맥주'}), confidence=0.5, lift=1.25)])

# %%
row = rules[15]
support = row[1]
ordered_st = row[2]
for item in ordered_st:
    lhs = ', '.join([x for x in item[0]])
    rhs = ', '.join([x for x in item[1]])
    confidence = item[2]
    lift = item[3]
    if lift>1 :
        print("{} => {} \t {} \t {} \t {}".format(lhs, rhs, support, confidence, lift))
# Out:
# 맥주 => 콜라, 와인 	 0.2 	 0.5 	 1.25
# 콜라 => 맥주, 와인 	 0.2 	 0.25 	 1.25
# 맥주, 와인 => 콜라 	 0.2 	 1.0 	 1.25
# 콜라, 와인 => 맥주 	 0.2 	 0.5 	 1.25

# %%
print('조건 -> 결과 \t\t\t 지지도\t신뢰도\t향상도')
for row in rules:
    support = row[1]
    ordered_st = row[2]
    for item in ordered_st:
        lhs = ', '.join([x for x in item[0]])
        rhs = ', '.join([x for x in item[1]])
        confidence = item[2]
        lift = item[3]
        if lift>1 :
            if (len(lhs)<=2) & (len(rhs)<=2):
                print("{} => {} \t\t\t {} \t {:.2f} \t {:.2f}".format(lhs, rhs, support, confidence, lift))
            else:
                print("{} => {} \t\t {} \t {:.2f} \t {:.2f}".format(lhs, rhs, support, confidence, lift))
# Out:
# 조건 -> 결과 			 지지도	신뢰도	향상도
# 맥주 => 콜라 			 0.4 	 1.00 	 1.25
# 콜라 => 맥주 			 0.4 	 0.50 	 1.25
# 소주 => 콜라 			 0.6 	 1.00 	 1.25
# 콜라 => 소주 			 0.6 	 0.75 	 1.25
# 콜라 => 맥주, 소주 		 0.2 	 0.25 	 1.25
# 맥주, 소주 => 콜라 		 0.2 	 1.00 	 1.25
# 맥주 => 콜라, 와인 		 0.2 	 0.50 	 1.25
# 콜라 => 맥주, 와인 		 0.2 	 0.25 	 1.25
# 맥주, 와인 => 콜라 		 0.2 	 1.00 	 1.25
# 콜라, 와인 => 맥주 		 0.2 	 0.50 	 1.25
# 소주 => 콜라, 오렌지주스 		 0.2 	 0.33 	 1.67
# 콜라 => 오렌지주스, 소주 		 0.2 	 0.25 	 1.25
# 오렌지주스, 소주 => 콜라 		 0.2 	 1.00 	 1.25
# 콜라, 오렌지주스 => 소주 		 0.2 	 1.00 	 1.67
# 콜라 => 와인, 소주 		 0.2 	 0.25 	 1.25
# 와인, 소주 => 콜라 		 0.2 	 1.00 	 1.25

# %%
import pandas as pd
rules_df = pd.DataFrame(None, columns=['lhs','rhs','support','confidence','lift'])
index=0
for row in rules:
    support = row[1]
    ordered_st = row[2]
    for item in ordered_st:
        lhs = ', '.join([x for x in item[0]])
        rhs = ', '.join([x for x in item[1]])
        confidence = item[2]
        lift = item[3]
        if lift>1 :
            rules_df.loc[index] = [lhs, rhs, support, confidence, lift]            
            index += 1
rules_df.sort_values(by=['confidence', 'lift'], ascending=False)
# Out:
#           lhs        rhs  support  confidence      lift
# 13  콜라, 오렌지주스         소주      0.2    1.000000  1.666667
# 0          맥주         콜라      0.4    1.000000  1.250000
# 2          소주         콜라      0.6    1.000000  1.250000
# 5      맥주, 소주         콜라      0.2    1.000000  1.250000
# 8      맥주, 와인         콜라      0.2    1.000000  1.250000
# 12  오렌지주스, 소주         콜라      0.2    1.000000  1.250000
# 15     와인, 소주         콜라      0.2    1.000000  1.250000
# 3          콜라         소주      0.6    0.750000  1.250000
# 1          콜라         맥주      0.4    0.500000  1.250000
# 6          맥주     콜라, 와인      0.2    0.500000  1.250000
# 9      콜라, 와인         맥주      0.2    0.500000  1.250000
# 10         소주  콜라, 오렌지주스      0.2    0.333333  1.666667
# 4          콜라     맥주, 소주      0.2    0.250000  1.250000
# 7          콜라     맥주, 와인      0.2    0.250000  1.250000
# 11         콜라  오렌지주스, 소주      0.2    0.250000  1.250000
# 14         콜라     와인, 소주      0.2    0.250000  1.250000

# %% [markdown]
# # 3. 뉴스 연관 분석
# - http://fs.jtbc.joins.com/RSS/economy.xml 기사 검색후 -> 명사 추출(기자, 앵커 제외) -> 연관분석(min_support=0.15, min_confident=0.1)

# %%
import requests
from bs4 import BeautifulSoup
from mecab import MeCab
from gensim.models import Word2Vec
from apyori import apriori
rss_url = "http://fs.jtbc.joins.com/RSS/economy.xml"
jtbc_economy = requests.get(rss_url)
soup = BeautifulSoup(jtbc_economy.content, 'xml')
link_ele = soup.select('item link')
link_list = [link.text for link in link_ele]
mecab = MeCab()
news = []
for link in link_list:
    response = requests.get(link)
    news_soup = BeautifulSoup(response.content, 'html.parser')
    title = news_soup.select_one('title').text
    content = str(news_soup.select_one('meta[name="description"]'))
    content = content.replace('<meta content="','').replace('" name ="description"/>','')
    noun_list = [word for word, tag in mecab.pos(title + ' ' + content) if tag in ('NNG', 'NNP')]
    noun_list = [noun for noun in noun_list if noun not in ('기자', '앵커')]
    news.append(noun_list)

rules = apriori(news, min_support=0.15, min_confidence=0.1)
rules = list(rules)
print(news)
# Out:
# [['둔촌', '주공', '전세', '홍수', '예상', '눈치', '게임', '시작', '뉴스', '단군', '최대', '규모', '재건축', '둔촌', '주공', '아파트', '입주', '다음', '달', '시작', '규모', '입주', '전세', '매물', '현장', '분위기', '이상', '다음', '달', '세대', '입주', '시작', '서울', '둔촌동', '올림픽', '파크', '포레', '온', '국내', '건축', '가운데', '역대', '최대', '규모', '이용택', '공인', '중개사', '공개', '행사', '이후', '가량', '판단', '연령', '세대', '관심', '단지', '입주', '시기', '전', '전세', '물량', '지도', '관심', '전', '세대', '입주', '서울', '헬리오', '시티', '당시', '전세', '매매', '가격', '동반', '하락', '이번', '현장', '김복수', '공인', '중개사', '일반', '아파트', '입주', '정도', '전세', '보통', '시장', '모습', '전세', '입주', '전세', '본인', '가격', '거주', '의무', '폐지', '신축', '선호', '현상', '가세', '전세', '매물', '자체', '부족', '인터넷', '매물', '세대', '최근', '정부', '대출', '관리', '전세', '대출', '규제', '점', '한몫', '권대', '서강대', '부동산', '학과', '교수', '전세', '대출', '세입자', '물량', '전세', '대출', '실입', '주', '현상', '임대', '물량', '상대', '전세', '집', '주인', '주변', '전셋값', '신축', '중심', '추세', '함영진', '직방', '빅', '데이터', '랩', '장', '규모', '입', '주장', '전세', '가격', '하락', '매물', '유통', '기대', '영상', '취재', '승규', '영상', '편집', '김지우'], ['실제', '캠', '핑장', '관리', '소홀', '뉴스', '캠', '핑장', '예약', '때', '예약', '플랫폼', '사진', '기대', '사진', '당황', '캠', '핑장', '사진', '앞', '예약', '업체', '책임', '아람', '인터넷', '카페', '글', '소비자', '캠', '핑장', '상태', '예약', '플랫폼', '사진', '불만', '토로', '사진', '신축', '건물', '신축', '글', '김정식', '피해자', '사이트', '사진', '글', '선택', '사기', '호소', '소비자', '입장', '한국', '소비', '자원', '조사', '캠핑', '예약', '플랫', '폼', '이용자', '플랫', '폼', '정보', '실제', '불편', '답', '그동안', '공정', '약관', '소비자', '보상', '길', '놀자', '때', '주요', '예약', '플랫', '폼', '약관', '정보', '정확', '신뢰도', '사업자', '책임', '면제', '조항', '앞', '실제', '모습', '사실', '경우', '플랫', '폼', '책임', '신용호', '공정위', '약관', '특수', '거래', '과장', '플랫', '폼', '사업자', '플랫', '폼', '운영', '관리', '주체', '관리자', '주', '의무', '이용자', '분쟁', '발생', '해결', '필요', '조치', '이행', '의무', '캠', '핑장', '사진', '정보', '최근', '실제', '모습', '플랫', '폼', '업체', '정기', '점검', '고지', '공정위', '약관', '시정', '캠', '핑장', '자연', '휴양림', '확대', '관계', '부처', '협의'], ['요즘', '편의점', '정도', '뉴스', '육박', '점심', '값', '편의점', '도시락', '때', '편의점', '도시락', '식비', '부담', '아람', '서울'], ['오늘', '말', '이유', '편의점', '도시락', '시대', '뉴스', '주머니', '직장인', '자취생', '편의점', '도시락', '편의점', '도시락', '눈앞', '아람', '서울', '편의점', '도시락'], ['경영', '분쟁', '주총', '표', '대결', '롤러코스터', '고려', '아연', '주가', '뉴스', '오늘', '고려', '아연', '주가', '장중', '포인트', '말', '롤러코스터', '공개매수', '절차', '마무리', '뚜껑', '양측', '과반', '확보', '실패', '결'], ['결혼', '돈', '걱정', '예비', '부부', '뉴스', '저출산', '문제', '결혼', '현실', '예비', '부부', '결혼식', '비용', '문제', '말', '소식', '아람', '내년', '결혼', '앞'], ['예비', '부부', '웨딩', '물가', '올해', '예식장', '비용', '뉴스', '한편', '결혼식', '비용', '예비', '부부', '말', '소식', '아람', '내년', '결혼', '정', '현대', '김세현', '본격', '결혼'], ['비정규직', '비중', '역대', '최고', '꼴', '뉴스', '비정규직', '임금', '근로자', '비정규직', '통계청', '기준', '임금', '근로자', '가운데', '비정규직', '전체', '차지'], ['대통령', '경제', '빨간불', '뉴스', '어제', '예상', '분기', '경제', '성장', '공개', '경제', '우려', '전', '대통령', '경제', '장담', '정부', '인식'], ['수출', '뒷걸음질', '분기', '경제', '성장률', '뉴스', '한국은행', '오늘', '경제', '분기', '성적표', '예상', '걱정', '소비', '개선', '경제', '효자', '역할', '수출', '공'], ['날개', '하이닉스', '삼성전자', '역대', '급', '실적', '뉴스', '하이닉스', '올해', '분기', '조원대', '영업', '이익', '기록', '사상', '최대', '실적', '고부', '가치', '메모리', '대역폭', '메모리', '영향', '삼성전자', '반도체', '실적'], ['배추', '정부', '중순', '뉴스', '배추', '가격', '최근', '평년', '대비', '배', '정부', '오늘', '수급', '안정', '대책', '김장', '속', '재료', '김'], ['내년', '추석', '황금연휴', '항공권', '예약', '전쟁', '뉴스', '내년', '추석', '얘기', '뒤', '준비', '사람', '최대', '열흘', '황금연휴', '여행', '계획', '매진', '항공', '노선도'], ['역대', '급', '여름', '폭염', '탓', '제철', '몸', '가을', '전어', '뉴스', '전어', '제철', '계절', '가을', '엇', '값', '배', '폭염', '조업', '량', '꽃게', '갈치', '상황', '생선', '인플레이션', '정도', '이상'], ['바다', '전어', '현실', '피시', '플레이', '션', '뉴스', '이상', '기온', '가을', '전어', '제철', '가격', '배', '여름', '폭염', '바닷물', '온도', '조업', '량', '탓', '꽃게', '갈치', '상황', '가을', '수산물'], ['정부', '자본', '잠식', '티', '재무', '상태', '예산', '책정', '뉴스', '티몬', '위', '미', '정산', '사태', '나기', '직전', '정부', '지원', '사업', '입점', '업체', '매출', '사실', '확인', '말', '판매자', '판매', '피해', '정부'], ['정부', '피해', '정부', '재무', '상태', '티몬', '지원', '뉴스', '티몬', '위', '미', '정산', '사태', '직전', '정부', '지원', '사업', '마지막', '입점', '업체', '매출', '사실', '취재', '결과', '확인', '지원', '예산', '책정', '정부', '재무', '상태'], ['이상', '아파트', '거래', '최근', '최고', '서울', '뉴스 ...

# %%
row = rules[15]
support = row[1]
ordered_st = row[2]
for item in ordered_st:
    lhs = ', '.join([x for x in item[0]])
    rhs = ', '.join([x for x in item[1]])
    confidence = item[2]
    lift = item[3]
    if lift>1 :
        print("{} => {} \t {} \t {} \t {}".format(lhs, rhs, support, confidence, lift))

# %%
import pandas as pd
rules_df = pd.DataFrame(None, columns=['lhs','rhs','support','confidence','lift'])
index=0
for row in rules:
    support = row[1]
    ordered_st = row[2]
    for item in ordered_st:
        lhs = ', '.join([x for x in item[0]])
        rhs = ', '.join([x for x in item[1]])
        confidence = item[2]
        lift = item[3]
        if lift>1 :
            rules_df.loc[index] = [lhs, rhs, support, confidence, lift]            
            index += 1
rules_df.sort_values(by=['confidence', 'lift'], ascending=False)
# Out:
#            lhs         rhs  support  confidence      lift
# 6           사실          상태     0.15        1.00  6.666667
# 7           상태          사실     0.15        1.00  6.666667
# 8           사실          업체     0.15        1.00  6.666667
# 9           업체          사실     0.15        1.00  6.666667
# 10          상태          업체     0.15        1.00  6.666667
# 11          업체          상태     0.15        1.00  6.666667
# 24          사실      뉴스, 상태     0.15        1.00  6.666667
# 25          상태      뉴스, 사실     0.15        1.00  6.666667
# 26      뉴스, 사실          상태     0.15        1.00  6.666667
# 27      뉴스, 상태          사실     0.15        1.00  6.666667
# 28          사실      뉴스, 업체     0.15        1.00  6.666667
# 29          업체      뉴스, 사실     0.15        1.00  6.666667
# 30      뉴스, 사실          업체     0.15        1.00  6.666667
# 31      뉴스, 업체          사실     0.15        1.00  6.666667
# 32          상태      뉴스, 업체     0.15        1.00  6.666667
# 33          업체      뉴스, 상태     0.15        1.00  6.666667
# 34      뉴스, 상태          업체     0.15        1.00  6.666667
# 35      뉴스, 업체          상태     0.15        1.00  6.666667
# 36          사실      업체, 상태     0.15        1.00  6.666667
# 37          상태      업체, 사실     0.15        1.00  6.666667
# 38          업체      사실, 상태     0.15        1.00  6.666667
# 39      상태, 사실          업체     0.15        1.00  6.666667
# 40      업체, 사실          상태     0.15        1.00  6.666667
# 41      업체, 상태          사실     0.15        1.00  6.666667
# 42          사실  뉴스, 상태, 업체     0.15        1.00  6.666667
# 43          상태  뉴스, 사실, 업체     0.15        1.00  6.666667
# 44          업체  사실, 뉴스, 상태     0.15        1.00  6.666667
# 45      뉴스, 사실      업체, 상태     0.15        1.00  6.666667
# 46      뉴스, 상태      업체, 사실     0.15        1.00  6.666667
# 47      뉴스, 업체      사실, 상태     0.15        1.00  6.666667
# 48      상태, 사실      뉴스, 업체     0.15        1.00  6.666667
# 49      업체, 사실      뉴스, 상태     0.15        1.00  6.666667
# 50      업체, 상태      뉴스, 사실     0.15        1.00  6.666667
# 51  뉴스, 상태, 사실          업체     0.15        1.00  6.666667
# 52  뉴스, 사실, 업체          상태     0.15        1.00  6.666667
# 53  뉴스, 상태, 업체          사실     0.15        1.00  6.666667
# 2           가격          최근     0.15        0.75  3.750000
# 3           최근          가격     0.15        0.75  3.750000
# 16          가격      뉴스, 최근     0.15        0.75  3.750000
# 17          최근      뉴스, 가격     0.15        0.75  3.750000
# 18      뉴스, 가격          최근     0.15        0.75  3.750000
# 19      뉴스, 최근          가격     0.15        0.75  3.750000
# 0           가격          이상     0.15        0.75  3.000000
# 12          가격      이상, 뉴스     0.15        0.75  3.000000
# 14      뉴스, 가격          이상     0.15        0.75  3.000000
# 1           이상          가격     0.15        0.60  3.000000
# 13          이상      뉴스, 가격     0.15        0.60  3.000000
# 15      이상, 뉴스          가격     0.15        0.60  3.000000
# 4            말          아람     0.15        0.60  2.400000
# 5           아람           말     0.15        0.60  2.400000
# 20           말      아람, 뉴스     0.15        0.60  2.400000
# 21          아람       말, 뉴스     0.15        0.60  2.400000
# 22       말, 뉴스          아람     0.15        0.60  2.400000
# 23      아람, 뉴스           말     0.15        0.60  2.400000
