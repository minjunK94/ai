# %% [markdown]
# ## 1. 기본적인 DNN

# %% [markdown]
# ## 2. 사이킷런(sklearn) 이용
# - 원핫인코딩을 하지 않고 라벨 인코딩까지만 해야 작동. 원핫인코딩은 작동되지 않음

# %%
from sklearn import datasets # iris 데이터
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.neural_network import MLPClassifier

# %%
# 1. 데이터
iris = datasets.load_iris()
iris_X = iris.data
iris_y = iris.target
print(iris_X[::50], iris_y[::50])
train_X, test_X, train_y, test_y = train_test_split(iris_X, iris_y,
                                                   test_size=0.3, # 기본값 = 0.75 : 0.25
                                                   random_state=4,
                                                   stratify = iris_y
                                                   )
print(train_X.shape, test_X.shape, test_y.shape, train_y.shape)
# Out:
# [[5.1 3.5 1.4 0.2]
#  [7.  3.2 4.7 1.4]
#  [6.3 3.3 6.  2.5]] [0 1 2]
# (105, 4) (45, 4) (45,) (105,)

# %%
# 사이킷런에서 제공하는 다층퍼셉트론 기반의 분류 알고리즘 api
mlp = MLPClassifier(hidden_layer_sizes=(50,30,20,10),
                    activation='relu',
                    solver='adam', # optimizer 설정값
                    max_iter = 1000, # 최대 학습횟수
                    early_stopping=True, # 조기 종료 활성화
                    n_iter_no_change=115, # 검증셋 손실함수가 개선되지 않으면 조기종료
                    validation_fraction=0.1 # 검증셋 비율
                   )

# %%
mlp.fit(train_X, train_y)
# Out:
# MLPClassifier(early_stopping=True, hidden_layer_sizes=(50, 30, 20, 10),
#               max_iter=1000, n_iter_no_change=115)

# %%
mlp.score(test_X, test_y)
# Out:
# 0.8444444444444444

# %%
mlp.predict(test_X[0:1])
# Out:
# array([0])

# %% [markdown]
# ## 3. 클래스를 생성 하여 DNN구현

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Input
from tensorflow.keras.callbacks import EarlyStopping
import matplotlib.pyplot as plt

# %%
class DNNClassifier:
    @staticmethod
    def build(input_dim=4,
             activation='relu',
             output_dim=3):
#         model = Sequential()
#         model.add(Input(input_dim,))
#         model.add(Dense(50, activation=activation))
#         model.add(Dense(30, activation=activation))
#         model.add(Dense(output_dim, activation='softmax'))
        model = Sequential([
            Input(input_dim,),
            Dense(50, activation=activation),
            Dense(30, activation=activation),
            Dense(output_dim, activation='softmax'),
        ])
        #학습 과정 설정
        model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
        return model

# %%
# 1. 데이터 생성 및 전처리
iris_Y = pd.get_dummies(iris_y).to_numpy()
# train_X, test_X, train_Y, test_y = train_test_split(iris_X, iris_y,
#                                                    test_size=0.3, # 기본값 = 0.75 : 0.25
#                                                    random_state=4,
#                                                    stratify = iris_y
#                                                    )
# print(train_X.shape, train_Y.shape, test_X.shape, test_y.shape)
# print(iris_Y[::50])
train_Y = pd.get_dummies(train_y).values
test_Y = pd.get_dummies(test_y).values
# 2. 모델 생성
model = DNNClassifier.build(input_dim=4,
                           activation='relu',
                           output_dim=3)
# 3. 모델 학습
earlystopping = EarlyStopping(patience=115)
hist = model.fit(train_X, train_Y, epochs=1000, validation_batch_size=0.1,
                callbacks=[earlystopping])
# Out:
# Epoch 1/1000
# 1/4 [======>.......................] - ETA: 2s - loss: 1.7173 - accuracy: 0.2812WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 4/4 [==============================] - 1s 5ms/step - loss: 1.5761 - accuracy: 0.3333
# Epoch 2/1000
# 1/4 [======>.......................] - ETA: 0s - loss: 1.3606 - accuracy: 0.3125WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 4/4 [==============================] - 0s 6ms/step - loss: 1.3198 - accuracy: 0.3048
# Epoch 3/1000
# 1/4 [======>.......................] - ETA: 0s - loss: 1.0967 - accuracy: 0.1562WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 4/4 [==============================] - 0s 6ms/step - loss: 1.1868 - accuracy: 0.2381
# Epoch 4/1000
# 1/4 [======>.......................] - ETA: 0s - loss: 1.1582 - accuracy: 0.3438WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 4/4 [==============================] - 0s 5ms/step - loss: 1.1101 - accuracy: 0.3333
# Epoch 5/1000
# 1/4 [======>.......................] - ETA: 0s - loss: 1.0396 - accuracy: 0.3438WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 4/4 [==============================] - 0s 4ms/step - loss: 1.0290 - accuracy: 0.2095
# Epoch 6/1000
# 1/4 [======>.......................] - ETA: 0s - loss: 0.9689 - accuracy: 0.3750WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 4/4 [==============================] - 0s 5ms/step - loss: 0.9704 - accuracy: 0.3333
# Epoch 7/1000
# 1/4 [======>.......................] - ETA: 0s - loss: 0.9450 - accuracy: 0.6562WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 4/4 [==============================] - 0s 4ms/step - loss: 0.9380 - accuracy: 0.5905
# Epoch 8/1000
# 1/4 [======>.......................] - ETA: 0s - loss: 0.8645 - accuracy: 0.7500WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 4/4 [==============================] - 0s 5ms/step - loss: 0.9025 - accuracy: 0.6571
# Epoch 9/1000
# 1/4 [======>.......................] - ETA: 0s - loss: 0.8825 - accuracy: 0.6250WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 4/4 [==============================] - 0s 3ms/step - loss: 0.8672 - accuracy: 0.6667
# Epoch 10/1000
# 1/4 [======>.......................] - ETA: 0s - loss: 0.8601 - accuracy: 0.6250WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 4/4 [==============================] - 0s 4ms/step - loss: 0.8286 - accuracy: 0.6667
# Epoch 11/1000
# 1/4 [======>.......................] - ETA: 0s - loss: 0.7820 - accuracy: 0.7188WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 4/4 [==============================] - 0s 5ms/step - loss: 0.7926 - accuracy: 0.6667
# Epoch 12/1000
# 1/4 [======>.......................] - ETA: 0s - loss: 0.7346 - accuracy: 0.7812WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 4/4 [==============================] - 0s 2ms/step - loss: 0.7644 - accuracy: 0.6857
# Epoch 13/1000
# 1/4 [======>.......................] - ETA: 0s - loss: 0.7758 - accuracy: 0.5938WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 4/4 [==============================] - 0s 5ms/step - loss: 0.7412 - accuracy: 0.6952
# Epoch 14/1000
# 1/4 [======>.......................] - ETA: 0s - loss: 0.7500 - accuracy: 0.6562WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 4/4 [==============================] - 0s 3ms/step - loss: 0.7167 - accuracy: 0.7333
# Epoch 15/1000
# 1/4 [======>.......................] - ETA: 0s - loss: 0.7342 - accuracy: 0.6250WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 4/4 [==============================] - 0s 6ms/step - loss: 0.6929 - accuracy: 0.7524
# Epoch 16/1000
# 1/4 [======>.......................] - ETA: 0s - loss: 0.6746 - accuracy: 0.7188WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 4/4 [==============================] - 0s 3ms/step - loss: 0.6713 - accuracy: 0.7810
# Epoch 17/1000
# 1/4 [======>.......................] - ETA: 0s - loss: 0.6764 - accuracy: 0.7188WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 4/4 [==============================] - 0s 12ms/step - loss: 0.6505 - accuracy: 0.7810
# Epoch 18/1000
# 1/4 [======>.......................] - ETA: 0s - loss: 0.6204 - accuracy: 0.8438WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 4/4 [==============================] - 0s 3ms/step - loss: 0.6325 - accuracy: 0.7048
# Epoch 19/1000
# 1/4 [======>.......................] - ETA: 0s - loss: 0.6755 - accuracy: 0.6250WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 4/4 [==============================] - 0s 5ms/step - loss: 0.6134 - accuracy: 0.6952
# Epoch 20/1000
# 1/4 [======>.......................] - ETA: 0s - loss: 0.6205 - accuracy: 0.6562WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5964 - accuracy: 0.7238
# Epoch 21/1000
# 1/4 [======>.......................] - ETA: 0s - loss: 0.5803 - accuracy: 0.7812WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 4/4 [==============================] - 0s 4ms/step - loss: 0.5818 - accuracy: 0.7619
# Epoch 22/1000
# 1/4 [======>.......................] - ETA: 0s - loss: 0.5112 - accuracy: 0.9688WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 4/4 [==============================] - 0s 5ms/step - loss: 0.5683 - accuracy: 0.8381
# Epoch 23/1000
# 1/4 [======>.......................] - ETA: 0s - loss: 0.5615 - accuracy: 0.8750WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 4/4 [==============================] - 0s 5ms/step - loss: 0.5570 - accuracy: 0.7810
# Epoch 24/1000
# 1/4 [======>.......................] - ETA: 0s - loss: 0.5071 - accuracy: 0.8125WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 4/4 [==============================] - 0s 6ms/step - loss: 0.5409 - accuracy: 0.7905
# Epoch 25/1000
# 1/4 [======>.......................] - ETA: 0s - loss: 0.5521 - accuracy: 0.8125WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 4/4 [==============================] - 0s 8ms/step - loss: 0.5310 - accuracy: 0.8667
# Epoch 26/1000
# 1/4 [======>.......................] - ETA: 0s - loss: 0.4844 - accuracy: 0.9062WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 4/4 [==============================] - 0s 6ms/step - loss: 0.5196 - accuracy: 0.8667
# Epoch 27/1000
# 1/4 [======>.......................] - ETA: 0s - loss: 0.4643 - accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 4/4 [==============================] - 0s 6ms/step - loss: 0.5078 - accuracy: 0.8381
# Epoch 28/1000
# 1/4 [======>.......................] - ETA: 0s - loss: 0.4949 - accuracy: 0.8125WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 4/4 [==============================] - 0s 4ms/step - loss: 0.4984 - accuracy: 0.8571
# Epoch 29/1000
# 1/4 [======>.......................] - ETA: 0s - loss: 0.4991 - accuracy: 0.9062WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 4/4 [==============================] - 0s 4ms/step - loss: 0.4886 - accuracy: 0.8381
# Epoch 30/1000
# 1/4 [======>.......................] - ETA: 0s - loss: 0.4718 - accuracy: 0.8125WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 4/4 [==============================] - 0s 3ms/step - loss: 0.4802 - accuracy: 0.8381
# Epoch 31/1000
# 1/4 [======>.......................] - ETA: 0s - loss: 0.4382 - accuracy: 0.7812WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 4/4 [==============================] - 0s 3ms/step - loss: 0.4731 - accuracy: 0.7238
# Epoch 32/1000
# 1/4 [======>.......................] - ETA: 0s - loss: 0.4990 - accuracy: 0.6562WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 4/4 [==============================] - 0s 4ms/step - loss: 0.4717 - accuracy: 0.6952
# Epoch 33/1000
# 1/4 [======>.......................] - ETA: 0s - loss: 0.5077 - accuracy: 0.6250WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 4/4 [==============================] - 0s 4ms/step - loss: 0.4636 - accuracy: 0.7048
# Epoch 34/1000
# 1/4 [======>.......................] - ETA: 0s - loss: 0.4810 - accuracy: 0.6875WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 4/4 [==============================] - 0s 4ms/step - loss: 0.4515 - accuracy: 0.7524
# Epoch 35/1000
# 1/4 [======>.......................] - ETA: 0s - loss: 0.3638 - accuracy: 0.9375WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 4/4 [==============================] - 0s 4ms/step - loss: 0.4420 - accuracy: 0.8762
# Epoch 36/1000
# 1/4 [======>.......................] - ETA: 0s - loss: 0.4196 - accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 4/4 [==============================] - 0s 4ms/step - loss: 0.4367 - accuracy: 0.9429
# Epoch 37/1000
# 1/4 [======>.......................] - ETA: 0s - loss: 0.4002 - accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 4/4 [==============================] - 0s 3ms/step - loss: 0.4321 - accuracy: 0.9048
# Epoch 38/1000
# 1/4 [======>.......................] - ETA: 0s - loss: 0.3416 - accuracy: 0.9688WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 4/4 [==============================] - 0s 3ms/step - loss: 0.4216 - accuracy: 0.9143
# Epoch 39/1000
# 1/4 [======>.......................] - ETA: 0s - loss: 0.4595 - accuracy: 0.9062WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 4/4 [==============================] - 0s 4ms/step - loss: 0.4159 - accuracy: 0.9333
# Epoch 40/1000
# 1/4 [======>.......................] - ETA: 0s - loss: 0.4337 - accuracy: 0.9375WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 4/4 [==============================] - 0s 3ms/step - loss: 0.4131 - accuracy: 0.9714
# Epoch 41/1000
# 1/4 [======>.......................] - ETA: 0s - loss: 0.4419 - accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 4/4 [==============================] - 0s 3ms/step - loss: 0.4056 - accuracy: 0.9905
# Epoch 42/1000
# 1/4 [======>.......................] - ETA: 0s - loss: 0.3988 - accuracy: 0.9688WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 4/4 [==============================] - 0s 3ms/step - loss: 0.3977 - accuracy: 0.9619
# Epoch 43/1000
# 1/4 [======>.......................] - ETA: 0s - loss: 0.4194 - accuracy: 0.9375WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 4/4 [==============================] - 0s 4ms/step - loss: 0.3933 - accuracy: 0.9143
# Epoch 44/1000
# 1/4 [======>.......................] - ETA: 0s - loss: 0.3794 - accuracy: 0.8750WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 4/4 [==============================] - 0s 3ms/step - loss: 0.3863 - accuracy: 0.9048
# Epoch 45/1000
# 1/4 [======>.......................] - ETA: 0s - loss: 0.3848 - accuracy: 0.9375WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 4/4 [==============================] - 0s 3ms/step - loss: 0.3803 - accuracy: 0.9619
# Epoch 46/1000
# 1/4 [======>.......................] - ETA: 0s - loss: 0.3916 - accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 4/4 [==============================] - 0s 8ms/step - loss: 0.3750 - accuracy: 0.9619
# Epoch 47/1000
# 1/4 [======>.......................] - ETA: 0s - loss: 0.3316 - accuracy: 0.9688WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 4/4 [==============================] - 0s 3ms/step - loss: 0.3699 - accuracy: 0.9333
# Epoch 48/1000
# 1/4 [======>.......................] - ETA: 0s - loss: 0.3317 - accuracy: 0.9062WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 4/4 [==============================] - 0s 4ms/step - loss: 0.3707 - accuracy: 0.8667
# Epoch 49/1000
# 1/4 [======>.......................] - ETA: 0s - loss: 0.4059 - accuracy: 0.8750WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 4/4 [==============================] - 0s 4ms/step - loss: 0.3601 - accuracy: 0.9238
# Epoch 50/1000
# 1/4 [======>.......................] - ETA: 0s - loss: 0.3259 - accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 4/4 [==============================] - 0s 3ms/step - loss: 0.3568 - accuracy: 0.9905
# Epoch 51/1000
# 1/4 [======>.......................] - ETA: 0s - loss: 0.3241 - accuracy: 0.9375WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 4/4 [==============================] - 0s 3ms/step - loss: 0.3528 - accuracy: 0.9714
# Epoch 52/1000
# 1/4 [======>.......................] - ETA: 0s - loss: 0.3795 - accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 4/4 [==============================] - 0s 4ms/step - loss: 0.3484 - accuracy: 0.9810
# Epoch 53/1000
# 1/4 [======>.......................] - ETA: 0s - loss: 0.3793 - accuracy: 0.8125WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 4/4 [==============================] - 0s 4ms/step - loss: 0.3410 - accuracy: 0.9048
# Epoch 54/1000
# 1/4 [======>.......................] - ETA: 0s - loss: 0.3183 - accuracy: 0.9688WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 4/4 [==============================] - 0s 4ms/step - loss: 0.3343 - accuracy: 0.9714
# Epoch 55/1000
# 1/4 [======>.......................] - ETA: 0s - loss: 0.3362 - accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 4/4 [==============================] - 0s 3ms/step - loss: 0.3295 - accuracy: 0.9905
# Epoch 56/1000
# 1/4 [======>.......................] - ETA: 0s - loss: 0.3188 - accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 4/4 [==============================] - 0s 3ms/step - loss: 0.3238 - accuracy: 0.9905
# Epoch 57/1000
# 1/4 [======>.......................] - ETA: 0s - loss: 0.3022 - accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 4/4 [==============================] - 0s 3ms/step - loss: 0.3181 - accuracy: 0.9905
# Epoch 58/1000
# 1/4 [======>.......................] - ETA: 0s - loss: 0.3039 - accuracy: 0.9688WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 4/4 [==============================] - 0s 4ms/step - loss: 0.3141 - accuracy: 0.9905
# Epoch 59/1000
# 1/4 [======>.......................] - ETA: 0s - loss: 0.2509 - accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 4/4 [==============================] - 0s 3ms/step - loss: 0.3066 - accuracy: 0.9810
# Epoch 60/1000
# 1/4 [======>.......................] - ETA: 0s - loss: 0.2983 - accuracy: 0.9062WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 4/4 [==============================] - 0s 3ms/step - loss: 0.3132 - accuracy: 0.8857
# Epoch 61/1000
# 1/4 [======>.......................] - ETA: 0s - loss: 0.3114 - accuracy: 0.8750WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 4/4 [==============================] - 0s 3ms/step - loss: 0.3083 - accuracy: 0.9143
# Epoch 62/1000
# 1/4 [======>.......................] - ETA: 0s - loss: 0.2888 - accuracy: 0.9688WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 4/4 [==============================] - 0s 3ms/step - loss: 0.2957 - accuracy: 0.9810
# Epoch 63/1000
# 1/4 [======>.......................] - ETA: 0s - loss: 0.2950 - accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2958 - accuracy: 0.9810
# Epoch 64/1000
# 1/4 [======>.......................] - ETA: 0s - loss: 0.3130 - accuracy: 0.9688WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 4/4 [==============================] - 0s 3ms/step - loss: 0.2889 - accuracy: 0.9810
# Epoch 65/1000
# 1/4 [======>.......................] - ETA: 0s - loss: 0.3155 - accuracy: 0.9688WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 4/4 [==============================] - 0s 3ms/step - loss: 0.2822 - accuracy: 0.9810
# Epoch 66/1000
# 1/4 [======>.......................] - ETA: 0s - loss: 0.2829 - accuracy: 0.9688WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 4/4 [==============================] - 0s 3ms/step - loss: 0.2794 - accuracy: 0.9524
# Epoch 67/1000
# 1/4 [======>.......................] - ETA: 0s - loss: 0.2721 - accuracy: 0.9688WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2725 - accuracy: 0.9810
# Epoch 68/1000
# 1/4 [======>.......................] - ETA: 0s - loss: 0.2769 - accuracy: 0.9688WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2689 - accuracy: 0.9905
# Epoch 69/1000
# 1/4 [======>.......................] - ETA: 0s - loss: 0.2886 - accuracy: 0.9688WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 4/4 [==============================] - 0s 3ms/step - loss: 0.2695 - accuracy: 0.9905
# Epoch 70/1000
# 1/4 [======>.......................] - ETA: 0s - loss: 0.2704 - accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 4/4 [==============================] - 0s 3ms/step - loss: 0.2601 - accuracy: 0.9905
# Epoch 71/1000
# 1/4 [======>.......................] - ETA: 0s - loss: 0.2736 - accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 4/4 [==============================] - 0s 3ms/step - loss: 0.2548 - accuracy: 0.9810
# Epoch 72/1000
# 1/4 [======>.......................] - ETA: 0s - loss: 0.2701 - accuracy: 0.9688WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2505 - accuracy: 0.9810
# Epoch 73/1000
# 1/4 [======>.......................] - ETA: 0s - loss: 0.2804 - accuracy: 0.9688WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2466 - accuracy: 0.9905
# Epoch 74/1000
# 1/4 [======>.......................] - ETA: 0s - loss: 0.2556 - accuracy: 0.9688WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2423 - accuracy: 0.9905
# Epoch 75/1000
# 1/4 [======>.......................] - ETA: 0s - loss: 0.2410 - accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 4/4 [==============================] - 0s 3ms/step - loss: 0.2375 - accuracy: 0.9905
# Epoch 76/1000
# 1/4 [======>.......................] - ETA: 0s - loss: 0.2360 - accuracy: 0.9688WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2344 - accuracy: 0.9905
# Epoch 77/1000
# 1/4 [======>.......................] - ETA: 0s - loss: 0.2378 - accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 4/4 [==============================] - 0s 3ms/step - loss: 0.2301 - accuracy: 0.9905
# Epoch 78/1000
# 1/4 [======>.......................] - ETA: 0s - loss: 0.2414 - accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 4/4 [==============================] - 0s 3ms/step - loss: 0.2235 - accuracy: 0.9905
# Epoch 79/1000
# 1/4 [======>.......................] - ETA: 0s - loss: 0.2504 - accuracy: 0.9688WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 4/4 [==============================] - 0s 3ms/step - loss: 0.2197 - accuracy: 0.9905
# Epoch 80/1000
# 1/4 [======>.......................] - ETA: 0s - loss: 0.2591 - accuracy: 0.9375WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 4/4 [==============================] - 0s 3ms/step - loss: 0.2150 - accuracy: 0.9810
# Epoch 81/1000
# 1/4 [======>.......................] - ETA: 0s - loss: 0.1802 - accuracy: 0.9688WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 4/4 [==============================] - 0s 3ms/step - loss: 0.2094 - accuracy: 0.9905
# Epoch 82/1000
# 1/4 [======>.......................] - ETA: 0s - loss: 0.1983 - accuracy: 0.9688WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 4/4 [==============================] - 0s 3ms/step - loss: 0.2074 - accuracy: 0.9905
# Epoch 83/1000
# 1/4 [======>.......................] - ETA: 0s - loss: 0.1878 - accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2018 - accuracy: 0.9905
# Epoch 84/1000
# 1/4 [======>.......................] - ETA: 0s - loss: 0.1858 - accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 4/4 [==============================] - 0s 3ms/step - loss: 0.2001 - accuracy: 0.9810
# Epoch 85/1000
# 1/4 [======>.......................] - ETA: 0s - loss: 0.2218 - accuracy: 0.9688WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1964 - accuracy: 0.9905
# Epoch 86/1000
# 1/4 [======>.......................] - ETA: 0s - loss: 0.1872 - accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1881 - accuracy: 0.9905
# Epoch 87/1000
# 1/4 [======>.......................] - ETA: 0s - loss: 0.1563 - accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1870 - accuracy: 0.9810
# Epoch 88/1000
# 1/4 [======>.......................] - ETA: 0s - loss: 0.1732 - accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1823 - accuracy: 0.9905
# Epoch 89/1000
# 1/4 [======>.......................] - ETA: 0s - loss: 0.2001 - accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1771 - accuracy: 0.9905
# Epoch 90/1000
# 1/4 [======>.......................] - ETA: 0s - loss: 0.1706 - accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1765 - accuracy: 0.9905
# Epoch 91/1000
# 1/4 [======>.......................] - ETA: 0s - loss: 0.1312 - accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1731 - accuracy: 0.9810
# Epoch 92/1000
# 1/4 [======>.......................] - ETA: 0s - loss: 0.1341 - accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1733 - accuracy: 0.9810
# Epoch 93/1000
# 1/4 [======>.......................] - ETA: 0s - loss: 0.1824 - accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1654 - accuracy: 0.9810
# Epoch 94/1000
# 1/4 [======>.......................] - ETA: 0s - loss: 0.1271 - accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1620 - accuracy: 0.9905
# Epoch 95/1000
# 1/4 [======>.......................] - ETA: 0s - loss: 0.1363 - accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1582 - accuracy: 0.9905
# Epoch 96/1000
# 1/4 [======>.......................] - ETA: 0s - loss: 0.1150 - accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1552 - accuracy: 0.9905
# Epoch 97/1000
# 1/4 [======>.......................] - ETA: 0s - loss: 0.1811 - accuracy: 0.9688WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1525 - accuracy: 0.9905
# Epoch 98/1000
# 1/4 [======>.......................] - ETA: 0s - loss: 0.1536 - accuracy: 0.9688WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1499 - accuracy: 0.9905
# Epoch 99/1000
# 1/4 [======>.......................] - ETA: 0s - loss: 0.1964 - accuracy: 0.9688WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1467 - accuracy: 0.9905
# Epoch 100/1000
# 1/4 [======>.......................] - ETA: 0s - loss: 0.2045 - accuracy: 0.9375WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1457 - accuracy: 0.9810
# Epoch 101/1000
# 1/4 [======>.......................] - ETA: 0s - loss: 0.1599 - accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1445 - accuracy: 0.9905
# Epoch 102/1000
# 1/4 [======>.......................] - ETA: 0s - loss: 0.1130 - accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1400 - accuracy: 0.9905
# Epoch 103/1000
# 1/4 [======>.......................] - ETA: 0s - loss: 0.1341 - accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1416 - accuracy: 0.9810
# Epoch 104/1000
# 1/4 [======>.......................] - ETA: 0s - loss: 0.1773 - accuracy: 0.9375WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1385 - accuracy: 0.9810
# Epoch 105/1000
# 1/4 [======>.......................] - ETA: 0s - loss: 0.1979 - accuracy: 0.9688WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1335 - accuracy: 0.9905
# Epoch 106/1000
# 1/4 [======>.......................] - ETA: 0s - loss: 0.1437 - accuracy: 0.9688WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1318 - accuracy: 0.9810
# Epoch 107/1000
# 1/4 [======>.......................] - ETA: 0s - loss: 0.1490 - accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 4/4 [==============================] - 0s 8ms/step - loss: 0.1276 - accuracy: 0.9905
# Epoch 108/1000
# 1/4 [======>.......................] - ETA: 0s - loss: 0.1413 - accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 4/4 [==============================] - 0s 5ms/step - loss: 0.1278 - accuracy: 0.9905
# Epoch 109/1000
# 1/4 [======>.......................] - ETA: 0s - loss: 0.1507 - accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1259 - accuracy: 0.9905
# Epoch 110/1000
# 1/4 [======>.......................] - ETA: 0s - loss: 0.1070 - accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1247 - accuracy: 0.9810
# Epoch 111/1000
# 1/4 [======>.......................] - ETA: 0s - loss: 0.1497 - accuracy: 0.9688WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1216 - accuracy: 0.9905
# Epoch 112/1000
# 1/4 [======>.......................] - ETA: 0s - loss: 0.1313 - accuracy: 0.9688WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 4/4 [==============================] - 0s 5ms/step - loss: 0.1210 - accuracy: 0.9905
# Epoch 113/1000
# 1/4 [======>.......................] - ETA: 0s - loss: 0.1410 - accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 4/4 [==============================] - 0s 5ms/step - loss: 0.1192 - accuracy: 0.9905
# Epoch 114/1000
# 1/4 [======>.......................] - ETA: 0s - loss: 0.1431 - accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1197 - accuracy: 0.9905
# Epoch 115/1000
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0984 - accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1174 - accuracy: 0.9905
# Epoch 116/1000
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0915 - accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1220 - accuracy: 0.9714
# Epoch 117/1000
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0810 - accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1164 - accuracy: 0.9905
# Epoch 118/1000
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0858 - accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1129 - accuracy: 0.9810
# Epoch 119/1000
# 1/4 [======>.......................] - ETA: 0s - loss: 0.1038 - accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1094 - accuracy: 0.9905
# Epoch 120/1000
# 1/4 [======>.......................] - ETA: 0s - loss: 0.1050 - accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1073 - accuracy: 0.9905
# Epoch 121/1000
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0882 - accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1067 - accuracy: 0.9905
# Epoch 122/1000
# 1/4 [======>.......................] - ETA: 0s - loss: 0.1006 - accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 4/4 [==============================] - 0s 5ms/step - loss: 0.1049 - accuracy: 0.9905
# Epoch 123/1000
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0845 - accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1039 - accuracy: 0.9905
# Epoch 124/1000
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0911 - accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1019 - accuracy: 0.9905
# Epoch 125/1000
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0943 - accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1010 - accuracy: 0.9905
# Epoch 126/1000
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0807 - accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1013 - accuracy: 0.9905
# Epoch 127/1000
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0987 - accuracy: 0.9688WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1034 - accuracy: 0.9810
# Epoch 128/1000
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0932 - accuracy: 0.9688WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0958 - accuracy: 0.9905
# Epoch 129/1000
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0688 - accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1088 - accuracy: 0.9810
# Epoch 130/1000
# 1/4 [======>.......................] - ETA: 0s - loss: 0.1405 - accuracy: 0.9688WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0959 - accuracy: 0.9905
# Epoch 131/1000
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0561 - accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1114 - accuracy: 0.9619
# Epoch 132/1000
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0889 - accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0986 - accuracy: 0.9905
# Epoch 133/1000
# 1/4 [======>.......................] - ETA: 0s - loss: 0.1501 - accuracy: 0.9688WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0975 - accuracy: 0.9810
# Epoch 134/1000
# 1/4 [======>.......................] - ETA: 0s - loss: 0.1028 - accuracy: 0.9688WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1016 - accuracy: 0.9810
# Epoch 135/1000
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0579 - accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0912 - accuracy: 0.9905
# Epoch 136/1000
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0701 - accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0920 - accuracy: 0.9905
# Epoch 137/1000
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0630 - accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0907 - accuracy: 0.9905
# Epoch 138/1000
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0538 - accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0883 - accuracy: 0.9905
# Epoch 139/1000
# 1/4 [======>.......................] - ETA: 0s - loss: 0.1343 - accuracy: 0.9688WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0881 - accuracy: 0.9905
# Epoch 140/1000
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0695 - accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0873 - accuracy: 0.9905
# Epoch 141/1000
# 1/4 [======>.......................] - ETA: 0s - loss: 0.1486 - accuracy: 0.9688WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0873 - accuracy: 0.9905
# Epoch 142/1000
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0763 - accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0879 - accuracy: 0.9810
# Epoch 143/1000
# 1/4 [======>.......................] - ETA: 0s - loss: 0.1013 - accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0845 - accuracy: 0.9905
# Epoch 144/1000
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0855 - accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0850 - accuracy: 0.9905
# Epoch 145/1000
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0991 - accuracy: 0.9688WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0830 - accuracy: 0.9905
# Epoch 146/1000
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0599 - accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0844 - accuracy: 0.9905
# Epoch 147/1000
# 1/4 [======>.......................] - ETA: 0s - loss: 0.1090 - accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0827 - accuracy: 0.9905
# Epoch 148/1000
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0706 - accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0844 - accuracy: 0.9905
# Epoch 149/1000
# 1/4 [======>.......................] - ETA: 0s - loss: 0.1371 - accuracy: 0.9688WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0827 - accuracy: 0.9905
# Epoch 150/1000
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0556 - accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0820 - accuracy: 0.9810
# Epoch 151/1000
# 1/4 [======>.......................] - ETA: 0s - loss: 0.1209 - accuracy: 0.9375WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0816 - accuracy: 0.9810
# Epoch 152/1000
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0726 - accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0790 - accuracy: 0.9905
# Epoch 153/1000
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0549 - accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0784 - accuracy: 0.9905
# Epoch 154/1000
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0811 - accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0772 - accuracy: 0.9905
# Epoch 155/1000
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0768 - accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0772 - accuracy: 0.9905
# Epoch 156/1000
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0538 - accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0771 - accuracy: 0.9905
# Epoch 157/1000
# ...
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0468 - accuracy: 0.9810
# Epoch 950/1000
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0039 - accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0384 - accuracy: 0.9905
# Epoch 951/1000
# 1/4 [======>.......................] - ETA: 0s - loss: 0.1213 - accuracy: 0.9688WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0477 - accuracy: 0.9810
# Epoch 952/1000
# 1/4 [======>.......................] - ETA: 0s - loss: 0.1226 - accuracy: 0.9688WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0490 - accuracy: 0.9905
# Epoch 953/1000
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0118 - accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0421 - accuracy: 0.9905
# Epoch 954/1000
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0901 - accuracy: 0.9688WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0396 - accuracy: 0.9905
# Epoch 955/1000
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0240 - accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0414 - accuracy: 0.9810
# Epoch 956/1000
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0213 - accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0402 - accuracy: 0.9905
# Epoch 957/1000
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0066 - accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0384 - accuracy: 0.9905
# Epoch 958/1000
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0262 - accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0413 - accuracy: 0.9905
# Epoch 959/1000
# 1/4 [======>.......................] - ETA: 0s - loss: 0.1274 - accuracy: 0.9688WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0424 - accuracy: 0.9905
# Epoch 960/1000
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0895 - accuracy: 0.9688WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0400 - accuracy: 0.9905
# Epoch 961/1000
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0241 - accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0396 - accuracy: 0.9905
# Epoch 962/1000
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0791 - accuracy: 0.9688WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0403 - accuracy: 0.9905
# Epoch 963/1000
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0212 - accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0408 - accuracy: 0.9905
# Epoch 964/1000
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0115 - accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0366 - accuracy: 0.9905
# Epoch 965/1000
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0143 - accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0452 - accuracy: 0.9810
# Epoch 966/1000
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0076 - accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0470 - accuracy: 0.9714
# Epoch 967/1000
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0489 - accuracy: 0.9688WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0402 - accuracy: 0.9810
# Epoch 968/1000
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0200 - accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0378 - accuracy: 0.9905
# Epoch 969/1000
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0044 - accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0432 - accuracy: 0.9905
# Epoch 970/1000
# 1/4 [======>.......................] - ETA: 0s - loss: 0.1121 - accuracy: 0.9688WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0427 - accuracy: 0.9905
# Epoch 971/1000
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0141 - accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0368 - accuracy: 0.9905
# Epoch 972/1000
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0848 - accuracy: 0.9688WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0401 - accuracy: 0.9905
# Epoch 973/1000
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0180 - accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0402 - accuracy: 0.9905
# Epoch 974/1000
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0085 - accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0365 - accuracy: 0.9905
# Epoch 975/1000
# 1/4 [======>.......................] - ETA: 0s - loss: 0.1070 - accuracy: 0.9688WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0424 - accuracy: 0.9905
# Epoch 976/1000
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0305 - accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0445 - accuracy: 0.9905
# Epoch 977/1000
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0119 - accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0336 - accuracy: 0.9905
# Epoch 978/1000
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0166 - accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0497 - accuracy: 0.9714
# Epoch 979/1000
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0759 - accuracy: 0.9375WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0518 - accuracy: 0.9714
# Epoch 980/1000
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0934 - accuracy: 0.9688WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0403 - accuracy: 0.9905
# Epoch 981/1000
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0081 - accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0465 - accuracy: 0.9905
# Epoch 982/1000
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0172 - accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0417 - accuracy: 0.9905
# Epoch 983/1000
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0291 - accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0362 - accuracy: 0.9905
# Epoch 984/1000
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0186 - accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0423 - accuracy: 0.9810
# Epoch 985/1000
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0496 - accuracy: 0.9688WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0504 - accuracy: 0.9714
# Epoch 986/1000
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0431 - accuracy: 0.9688WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0440 - accuracy: 0.9810
# Epoch 987/1000
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0973 - accuracy: 0.9688WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0403 - accuracy: 0.9905
# Epoch 988/1000
# 1/4 [======>.......................] - ETA: 0s - loss: 0.1045 - accuracy: 0.9688WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0427 - accuracy: 0.9905
# Epoch 989/1000
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0147 - accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0392 - accuracy: 0.9905
# Epoch 990/1000
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0885 - accuracy: 0.9688WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0408 - accuracy: 0.9905
# Epoch 991/1000
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0132 - accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0403 - accuracy: 0.9905
# Epoch 992/1000
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0407 - accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0446 - accuracy: 0.9905
# Epoch 993/1000
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0044 - accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0390 - accuracy: 0.9905
# Epoch 994/1000
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0678 - accuracy: 0.9688WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0446 - accuracy: 0.9714
# Epoch 995/1000
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0096 - accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0442 - accuracy: 0.9905
# Epoch 996/1000
# 1/4 [======>.......................] - ETA: 0s - loss: 0.1029 - accuracy: 0.9688WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0383 - accuracy: 0.9905
# Epoch 997/1000
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0373 - accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0381 - accuracy: 0.9905
# Epoch 998/1000
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0641 - accuracy: 0.9688WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0537 - accuracy: 0.9714
# Epoch 999/1000
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0552 - accuracy: 0.9688WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0391 - accuracy: 0.9810
# Epoch 1000/1000
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0141 - accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0422 - accuracy: 0.9905

# %%
loss, accuracy = model.evaluate(test_X, test_Y)
print(f'정확도 : {accuracy*100}%')
# Out:
# 2/2 [==============================] - 0s 5ms/step - loss: 0.1273 - accuracy: 0.9556
# 정확도 : 95.55555582046509%

# %%
model.predict(test_X[0].reshape(1,-1)).argmax(axis=1)
# Out:
# 1/1 [==============================] - 0s 83ms/step
# array([0], dtype=int64)

# %% [markdown]
# ## 4. 병렬처리

# %%
from tensorflow.keras.layers import concatenate
from tensorflow.keras import Model

# %%
train_X.shape, train_Y.shape, test_X.shape, test_Y.shape
# Out:
# ((105, 4), (105, 3), (45, 4), (45, 3))

# %%
# 모델 구성
input_ = Input(shape=(4, ))
dense1 = Dense(units=50, activation='relu')(input_)
dense2 = Dense(units=80, activation='relu')(input_)
dense3 = Dense(units=30, activation='relu')(input_)
x = concatenate([dense1, dense2, dense3])
# x = Dense(units=160, activation='relu')(input_) 의 병렬처리 구현
output = Dense(units=3, activation='softmax')(x)
model = Model(inputs=input_, outputs=output)
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_4 (InputLayer)           [(None, 4)]          0           []
#
#  dense_10 (Dense)               (None, 50)           250         ['input_4[0][0]']
#
#  dense_11 (Dense)               (None, 80)           400         ['input_4[0][0]']
#
#  dense_12 (Dense)               (None, 30)           150         ['input_4[0][0]']
#
#  concatenate_1 (Concatenate)    (None, 160)          0           ['dense_10[0][0]',
#                                                                   'dense_11[0][0]',
#                                                                   'dense_12[0][0]']
#
#  dense_13 (Dense)               (None, 3)            483         ['concatenate_1[0][0]']
#
# ==================================================================================================
# Total params: 1,283
# Trainable params: 1,283
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
# 학습 정의(설정), 학습
model.compile(loss='categorical_crossentropy',
             optimizer='adam',
             metrics=['accuracy'])
model.fit(train_X, train_Y,
         epochs=200,
         verbose=1)
# Out:
# Epoch 1/200
# 4/4 [==============================] - 1s 6ms/step - loss: 1.3421 - accuracy: 0.2952
# Epoch 2/200
# 4/4 [==============================] - 0s 6ms/step - loss: 1.2215 - accuracy: 0.3619
# Epoch 3/200
# 4/4 [==============================] - 0s 6ms/step - loss: 1.1188 - accuracy: 0.3524
# Epoch 4/200
# 4/4 [==============================] - 0s 8ms/step - loss: 1.0218 - accuracy: 0.3905
# Epoch 5/200
# 4/4 [==============================] - 0s 6ms/step - loss: 0.9332 - accuracy: 0.5048
# Epoch 6/200
# 4/4 [==============================] - 0s 10ms/step - loss: 0.8634 - accuracy: 0.6667
# Epoch 7/200
# 4/4 [==============================] - 0s 10ms/step - loss: 0.8046 - accuracy: 0.9238
# Epoch 8/200
# 4/4 [==============================] - 0s 8ms/step - loss: 0.7413 - accuracy: 0.8952
# Epoch 9/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.6877 - accuracy: 0.8476
# Epoch 10/200
# 4/4 [==============================] - 0s 6ms/step - loss: 0.6542 - accuracy: 0.7619
# Epoch 11/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.6137 - accuracy: 0.8000
# Epoch 12/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.5815 - accuracy: 0.8952
# Epoch 13/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.5575 - accuracy: 0.9429
# Epoch 14/200
# 4/4 [==============================] - 0s 6ms/step - loss: 0.5423 - accuracy: 0.9238
# Epoch 15/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5179 - accuracy: 0.9429
# Epoch 16/200
# 4/4 [==============================] - 0s 6ms/step - loss: 0.4958 - accuracy: 0.9429
# Epoch 17/200
# 4/4 [==============================] - 0s 6ms/step - loss: 0.4795 - accuracy: 0.9429
# Epoch 18/200
# 4/4 [==============================] - 0s 6ms/step - loss: 0.4652 - accuracy: 0.9429
# Epoch 19/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.4525 - accuracy: 0.9429
# Epoch 20/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.4405 - accuracy: 0.9429
# Epoch 21/200
# 4/4 [==============================] - 0s 6ms/step - loss: 0.4298 - accuracy: 0.9429
# Epoch 22/200
# 4/4 [==============================] - 0s 6ms/step - loss: 0.4193 - accuracy: 0.9429
# Epoch 23/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.4090 - accuracy: 0.9619
# Epoch 24/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.4005 - accuracy: 0.9333
# Epoch 25/200
# 4/4 [==============================] - 0s 6ms/step - loss: 0.3926 - accuracy: 0.9238
# Epoch 26/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.3836 - accuracy: 0.9333
# Epoch 27/200
# 4/4 [==============================] - 0s 6ms/step - loss: 0.3746 - accuracy: 0.9619
# Epoch 28/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.3712 - accuracy: 0.9619
# Epoch 29/200
# 4/4 [==============================] - 0s 6ms/step - loss: 0.3630 - accuracy: 0.9714
# Epoch 30/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.3545 - accuracy: 0.9619
# Epoch 31/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.3469 - accuracy: 0.9619
# Epoch 32/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.3401 - accuracy: 0.9619
# Epoch 33/200
# 4/4 [==============================] - 0s 6ms/step - loss: 0.3382 - accuracy: 0.9238
# Epoch 34/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.3304 - accuracy: 0.9524
# Epoch 35/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.3226 - accuracy: 0.9619
# Epoch 36/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.3196 - accuracy: 0.9714
# Epoch 37/200
# 4/4 [==============================] - 0s 11ms/step - loss: 0.3138 - accuracy: 0.9619
# Epoch 38/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.3076 - accuracy: 0.9619
# Epoch 39/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.3021 - accuracy: 0.9619
# Epoch 40/200
# 4/4 [==============================] - 0s 6ms/step - loss: 0.2972 - accuracy: 0.9619
# Epoch 41/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.2937 - accuracy: 0.9619
# Epoch 42/200
# 4/4 [==============================] - 0s 6ms/step - loss: 0.2888 - accuracy: 0.9619
# Epoch 43/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.2843 - accuracy: 0.9619
# Epoch 44/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2795 - accuracy: 0.9619
# Epoch 45/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2732 - accuracy: 0.9619
# Epoch 46/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2734 - accuracy: 0.9619
# Epoch 47/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2653 - accuracy: 0.9714
# Epoch 48/200
# 4/4 [==============================] - 0s 8ms/step - loss: 0.2632 - accuracy: 0.9619
# Epoch 49/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.2629 - accuracy: 0.9619
# Epoch 50/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2544 - accuracy: 0.9619
# Epoch 51/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2525 - accuracy: 0.9619
# Epoch 52/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2456 - accuracy: 0.9714
# Epoch 53/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.2472 - accuracy: 0.9619
# Epoch 54/200
# 4/4 [==============================] - 0s 6ms/step - loss: 0.2419 - accuracy: 0.9714
# Epoch 55/200
# 4/4 [==============================] - 0s 6ms/step - loss: 0.2356 - accuracy: 0.9714
# Epoch 56/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2335 - accuracy: 0.9619
# Epoch 57/200
# 4/4 [==============================] - 0s 6ms/step - loss: 0.2299 - accuracy: 0.9714
# Epoch 58/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2248 - accuracy: 0.9714
# Epoch 59/200
# 4/4 [==============================] - 0s 6ms/step - loss: 0.2242 - accuracy: 0.9619
# Epoch 60/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2239 - accuracy: 0.9619
# Epoch 61/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2167 - accuracy: 0.9714
# Epoch 62/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2145 - accuracy: 0.9810
# Epoch 63/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2140 - accuracy: 0.9714
# Epoch 64/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2098 - accuracy: 0.9714
# Epoch 65/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2033 - accuracy: 0.9810
# Epoch 66/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2074 - accuracy: 0.9619
# Epoch 67/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.2013 - accuracy: 0.9714
# Epoch 68/200
# 4/4 [==============================] - 0s 12ms/step - loss: 0.1988 - accuracy: 0.9619
# Epoch 69/200
# 4/4 [==============================] - 0s 8ms/step - loss: 0.1949 - accuracy: 0.9714
# Epoch 70/200
# 4/4 [==============================] - 0s 6ms/step - loss: 0.1919 - accuracy: 0.9714
# Epoch 71/200
# 4/4 [==============================] - 0s 10ms/step - loss: 0.1899 - accuracy: 0.9714
# Epoch 72/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.1871 - accuracy: 0.9714
# Epoch 73/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.1852 - accuracy: 0.9714
# Epoch 74/200
# 4/4 [==============================] - 0s 6ms/step - loss: 0.1831 - accuracy: 0.9714
# Epoch 75/200
# 4/4 [==============================] - 0s 6ms/step - loss: 0.1796 - accuracy: 0.9714
# Epoch 76/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.1790 - accuracy: 0.9714
# Epoch 77/200
# 4/4 [==============================] - 0s 6ms/step - loss: 0.1760 - accuracy: 0.9714
# Epoch 78/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.1741 - accuracy: 0.9810
# Epoch 79/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.1715 - accuracy: 0.9810
# Epoch 80/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.1703 - accuracy: 0.9810
# Epoch 81/200
# 4/4 [==============================] - 0s 6ms/step - loss: 0.1683 - accuracy: 0.9714
# Epoch 82/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.1673 - accuracy: 0.9810
# Epoch 83/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.1641 - accuracy: 0.9810
# Epoch 84/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.1630 - accuracy: 0.9714
# Epoch 85/200
# 4/4 [==============================] - 0s 6ms/step - loss: 0.1616 - accuracy: 0.9810
# Epoch 86/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.1582 - accuracy: 0.9810
# Epoch 87/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1563 - accuracy: 0.9714
# Epoch 88/200
# 4/4 [==============================] - 0s 6ms/step - loss: 0.1591 - accuracy: 0.9714
# Epoch 89/200
# 4/4 [==============================] - 0s 13ms/step - loss: 0.1561 - accuracy: 0.9810
# Epoch 90/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.1513 - accuracy: 0.9810
# Epoch 91/200
# 4/4 [==============================] - 0s 6ms/step - loss: 0.1506 - accuracy: 0.9810
# Epoch 92/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.1489 - accuracy: 0.9810
# Epoch 93/200
# 4/4 [==============================] - 0s 6ms/step - loss: 0.1539 - accuracy: 0.9714
# Epoch 94/200
# 4/4 [==============================] - 0s 6ms/step - loss: 0.1488 - accuracy: 0.9810
# Epoch 95/200
# 4/4 [==============================] - 0s 6ms/step - loss: 0.1438 - accuracy: 0.9810
# Epoch 96/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.1432 - accuracy: 0.9810
# Epoch 97/200
# 4/4 [==============================] - 0s 6ms/step - loss: 0.1420 - accuracy: 0.9810
# Epoch 98/200
# 4/4 [==============================] - 0s 6ms/step - loss: 0.1425 - accuracy: 0.9714
# Epoch 99/200
# 4/4 [==============================] - 0s 6ms/step - loss: 0.1391 - accuracy: 0.9810
# Epoch 100/200
# 4/4 [==============================] - 0s 6ms/step - loss: 0.1378 - accuracy: 0.9810
# Epoch 101/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.1367 - accuracy: 0.9810
# Epoch 102/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.1342 - accuracy: 0.9810
# Epoch 103/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.1340 - accuracy: 0.9810
# Epoch 104/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.1336 - accuracy: 0.9810
# Epoch 105/200
# 4/4 [==============================] - 0s 6ms/step - loss: 0.1298 - accuracy: 0.9810
# Epoch 106/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.1292 - accuracy: 0.9810
# Epoch 107/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1311 - accuracy: 0.9810
# Epoch 108/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.1282 - accuracy: 0.9810
# Epoch 109/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.1258 - accuracy: 0.9810
# Epoch 110/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1248 - accuracy: 0.9810
# Epoch 111/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.1238 - accuracy: 0.9810
# Epoch 112/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.1226 - accuracy: 0.9810
# Epoch 113/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1215 - accuracy: 0.9810
# Epoch 114/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.1206 - accuracy: 0.9810
# Epoch 115/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.1214 - accuracy: 0.9810
# Epoch 116/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.1185 - accuracy: 0.9810
# Epoch 117/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1196 - accuracy: 0.9905
# Epoch 118/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1229 - accuracy: 0.9714
# Epoch 119/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1197 - accuracy: 0.9714
# Epoch 120/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.1161 - accuracy: 0.9810
# Epoch 121/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.1147 - accuracy: 0.9810
# Epoch 122/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1133 - accuracy: 0.9810
# Epoch 123/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.1120 - accuracy: 0.9810
# Epoch 124/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1114 - accuracy: 0.9810
# Epoch 125/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.1103 - accuracy: 0.9810
# Epoch 126/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.1092 - accuracy: 0.9810
# Epoch 127/200
# 4/4 [==============================] - 0s 6ms/step - loss: 0.1096 - accuracy: 0.9810
# Epoch 128/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.1092 - accuracy: 0.9810
# Epoch 129/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.1075 - accuracy: 0.9810
# Epoch 130/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.1064 - accuracy: 0.9810
# Epoch 131/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.1058 - accuracy: 0.9810
# Epoch 132/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.1064 - accuracy: 0.9810
# Epoch 133/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.1046 - accuracy: 0.9810
# Epoch 134/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.1033 - accuracy: 0.9810
# Epoch 135/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.1030 - accuracy: 0.9810
# Epoch 136/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.1022 - accuracy: 0.9810
# Epoch 137/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.1021 - accuracy: 0.9810
# Epoch 138/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.1011 - accuracy: 0.9810
# Epoch 139/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1015 - accuracy: 0.9905
# Epoch 140/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.1080 - accuracy: 0.9810
# Epoch 141/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1009 - accuracy: 0.9810
# Epoch 142/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0968 - accuracy: 0.9810
# Epoch 143/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.1037 - accuracy: 0.9810
# Epoch 144/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0999 - accuracy: 0.9810
# Epoch 145/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0969 - accuracy: 0.9905
# Epoch 146/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0969 - accuracy: 0.9905
# Epoch 147/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0946 - accuracy: 0.9810
# Epoch 148/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0953 - accuracy: 0.9810
# Epoch 149/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0952 - accuracy: 0.9810
# Epoch 150/200
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0932 - accuracy: 0.9905
# Epoch 151/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0990 - accuracy: 0.9810
# Epoch 152/200
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0963 - accuracy: 0.9714
# Epoch 153/200
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0935 - accuracy: 0.9810
# Epoch 154/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0935 - accuracy: 0.9810
# Epoch 155/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0917 - accuracy: 0.9810
# Epoch 156/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0898 - accuracy: 0.9810
# Epoch 157/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0899 - accuracy: 0.9810
# Epoch 158/200
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0911 - accuracy: 0.9810
# Epoch 159/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0902 - accuracy: 0.9810
# Epoch 160/200
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0887 - accuracy: 0.9905
# Epoch 161/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0875 - accuracy: 0.9810
# Epoch 162/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0867 - accuracy: 0.9810
# Epoch 163/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0891 - accuracy: 0.9810
# Epoch 164/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0890 - accuracy: 0.9810
# Epoch 165/200
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0863 - accuracy: 0.9905
# Epoch 166/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0873 - accuracy: 0.9905
# Epoch 167/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0857 - accuracy: 0.9905
# Epoch 168/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0863 - accuracy: 0.9905
# Epoch 169/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0845 - accuracy: 0.9905
# Epoch 170/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0852 - accuracy: 0.9810
# Epoch 171/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0838 - accuracy: 0.9810
# Epoch 172/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0835 - accuracy: 0.9810
# Epoch 173/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0841 - accuracy: 0.9810
# Epoch 174/200
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0824 - accuracy: 0.9905
# Epoch 175/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0828 - accuracy: 0.9810
# Epoch 176/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0844 - accuracy: 0.9810
# Epoch 177/200
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0825 - accuracy: 0.9810
# Epoch 178/200
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0811 - accuracy: 0.9905
# Epoch 179/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0806 - accuracy: 0.9905
# Epoch 180/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0800 - accuracy: 0.9810
# Epoch 181/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0834 - accuracy: 0.9810
# Epoch 182/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0789 - accuracy: 0.9810
# Epoch 183/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0923 - accuracy: 0.9619
# Epoch 184/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0872 - accuracy: 0.9714
# Epoch 185/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0788 - accuracy: 0.9810
# Epoch 186/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0865 - accuracy: 0.9810
# Epoch 187/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0866 - accuracy: 0.9810
# Epoch 188/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0787 - accuracy: 0.9810
# Epoch 189/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0765 - accuracy: 0.9905
# Epoch 190/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0866 - accuracy: 0.9714
# Epoch 191/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0842 - accuracy: 0.9619
# Epoch 192/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0798 - accuracy: 0.9810
# Epoch 193/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0799 - accuracy: 0.9810
# Epoch 194/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0804 - accuracy: 0.9810
# Epoch 195/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0781 - accuracy: 0.9810
# Epoch 196/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0749 - accuracy: 0.9905
# Epoch 197/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0748 - accuracy: 0.9905
# Epoch 198/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0750 - accuracy: 0.9905
# Epoch 199/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0738 - accuracy: 0.9905
# Epoch 200/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0750 - accuracy: 0.9810

# %%
# 학습 평가
loss, accuracy = model.evaluate(test_X, test_Y)
print(accuracy*100, '%')
# Out:
# 2/2 [==============================] - 0s 5ms/step - loss: 0.1148 - accuracy: 0.9556
# 95.55555582046509 %
