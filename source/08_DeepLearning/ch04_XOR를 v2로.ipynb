# %%
import numpy as np
from tensorflow.keras.models import Sequential   # 모델 객체 생성
from tensorflow.keras.layers import Dense, Input # 모델 layer 쌓을 때 필요한 함수
import matplotlib.pyplot as plt

# %%
# 1. dataset
x_data = np.array([[0,0],[0,1],[1,0],[1,1]])
y_data = np.array([[0],[1],[1],[0]])
# 2. 모델 구성
model = Sequential()
# model.add(Input(shape=2))
model.add(Dense(units=10,
               input_dim=2, #input_shape=(2,)
               activation='relu'))
model.add(Dense(units=20, 
                activation='relu')) # 은닉층(hidden layer)에서는 input_shape를 X
model.add(Dense(units=10, 
                activation='relu'))
model.add(Dense(units=1, 
                activation='sigmoid'))
print(model.summary())
# 3. 모델 학습과정 설정
# model.compile(loss='mse', optimizer='adam', metrics=['mae']) 회귀식에서 학습과정 설정
model.compile(loss='binary_crossentropy', 
              optimizer='adam', 
              metrics=['binary_accuracy']) # 2진분류
# model.compile(loss='categorical_crossentropy', 
               # optimizer='adam', metrics=['accuracy']) # 다중분류
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 10)                30
#
#  dense_1 (Dense)             (None, 20)                220
#
#  dense_2 (Dense)             (None, 10)                210
#
#  dense_3 (Dense)             (None, 1)                 11
#
# =================================================================
# Total params: 471
# Trainable params: 471
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
# 4. 학습
hist = model.fit(x_data, y_data, 
                 epochs=200, 
                 verbose=2)
# Out:
# Epoch 1/200
# 1/1 - 0s - loss: 0.5148 - binary_accuracy: 1.0000 - 9ms/epoch - 9ms/step
# Epoch 2/200
# 1/1 - 0s - loss: 0.5117 - binary_accuracy: 1.0000 - 7ms/epoch - 7ms/step
# Epoch 3/200
# 1/1 - 0s - loss: 0.5086 - binary_accuracy: 1.0000 - 8ms/epoch - 8ms/step
# Epoch 4/200
# 1/1 - 0s - loss: 0.5056 - binary_accuracy: 1.0000 - 11ms/epoch - 11ms/step
# Epoch 5/200
# 1/1 - 0s - loss: 0.5025 - binary_accuracy: 1.0000 - 6ms/epoch - 6ms/step
# Epoch 6/200
# 1/1 - 0s - loss: 0.4994 - binary_accuracy: 1.0000 - 6ms/epoch - 6ms/step
# Epoch 7/200
# 1/1 - 0s - loss: 0.4963 - binary_accuracy: 1.0000 - 8ms/epoch - 8ms/step
# Epoch 8/200
# 1/1 - 0s - loss: 0.4931 - binary_accuracy: 1.0000 - 11ms/epoch - 11ms/step
# Epoch 9/200
# 1/1 - 0s - loss: 0.4899 - binary_accuracy: 1.0000 - 5ms/epoch - 5ms/step
# Epoch 10/200
# 1/1 - 0s - loss: 0.4868 - binary_accuracy: 1.0000 - 6ms/epoch - 6ms/step
# Epoch 11/200
# 1/1 - 0s - loss: 0.4836 - binary_accuracy: 1.0000 - 8ms/epoch - 8ms/step
# Epoch 12/200
# 1/1 - 0s - loss: 0.4804 - binary_accuracy: 1.0000 - 10ms/epoch - 10ms/step
# Epoch 13/200
# 1/1 - 0s - loss: 0.4770 - binary_accuracy: 1.0000 - 6ms/epoch - 6ms/step
# Epoch 14/200
# 1/1 - 0s - loss: 0.4736 - binary_accuracy: 1.0000 - 7ms/epoch - 7ms/step
# Epoch 15/200
# 1/1 - 0s - loss: 0.4700 - binary_accuracy: 1.0000 - 7ms/epoch - 7ms/step
# Epoch 16/200
# 1/1 - 0s - loss: 0.4663 - binary_accuracy: 1.0000 - 4ms/epoch - 4ms/step
# Epoch 17/200
# 1/1 - 0s - loss: 0.4625 - binary_accuracy: 1.0000 - 7ms/epoch - 7ms/step
# Epoch 18/200
# 1/1 - 0s - loss: 0.4586 - binary_accuracy: 1.0000 - 9ms/epoch - 9ms/step
# Epoch 19/200
# 1/1 - 0s - loss: 0.4546 - binary_accuracy: 1.0000 - 7ms/epoch - 7ms/step
# Epoch 20/200
# 1/1 - 0s - loss: 0.4507 - binary_accuracy: 1.0000 - 6ms/epoch - 6ms/step
# Epoch 21/200
# 1/1 - 0s - loss: 0.4468 - binary_accuracy: 1.0000 - 7ms/epoch - 7ms/step
# Epoch 22/200
# 1/1 - 0s - loss: 0.4430 - binary_accuracy: 1.0000 - 5ms/epoch - 5ms/step
# Epoch 23/200
# 1/1 - 0s - loss: 0.4391 - binary_accuracy: 1.0000 - 9ms/epoch - 9ms/step
# Epoch 24/200
# 1/1 - 0s - loss: 0.4352 - binary_accuracy: 1.0000 - 8ms/epoch - 8ms/step
# Epoch 25/200
# 1/1 - 0s - loss: 0.4313 - binary_accuracy: 1.0000 - 8ms/epoch - 8ms/step
# Epoch 26/200
# 1/1 - 0s - loss: 0.4273 - binary_accuracy: 1.0000 - 4ms/epoch - 4ms/step
# Epoch 27/200
# 1/1 - 0s - loss: 0.4233 - binary_accuracy: 1.0000 - 6ms/epoch - 6ms/step
# Epoch
- binary_accuracy: 1.0000 - 8ms/epoch - 8ms/step
# Epoch 182/200
# 1/1 - 0s - loss: 0.0507 - binary_accuracy: 1.0000 - 5ms/epoch - 5ms/step
# Epoch 183/200
# 1/1 - 0s - loss: 0.0501 - binary_accuracy: 1.0000 - 7ms/epoch - 7ms/step
# Epoch 184/200
# 1/1 - 0s - loss: 0.0495 - binary_accuracy: 1.0000 - 6ms/epoch - 6ms/step
# Epoch 185/200
# 1/1 - 0s - loss: 0.0488 - binary_accuracy: 1.0000 - 5ms/epoch - 5ms/step
# Epoch 186/200
# 1/1 - 0s - loss: 0.0482 - binary_accuracy: 1.0000 - 8ms/epoch - 8ms/step
# Epoch 187/200
# 1/1 - 0s - loss: 0.0476 - binary_accuracy: 1.0000 - 7ms/epoch - 7ms/step
# Epoch 188/200
# 1/1 - 0s - loss: 0.0470 - binary_accuracy: 1.0000 - 6ms/epoch - 6ms/step
# Epoch 189/200
# 1/1 - 0s - loss: 0.0464 - binary_accuracy: 1.0000 - 7ms/epoch - 7ms/step
# Epoch 190/200
# 1/1 - 0s - loss: 0.0458 - binary_accuracy: 1.0000 - 5ms/epoch - 5ms/step
# Epoch 191/200
# 1/1 - 0s - loss: 0.0453 - binary_accuracy: 1.0000 - 7ms/epoch - 7ms/step
# Epoch 192/200
# 1/1 - 0s - loss: 0.0447 - binary_accuracy: 1.0000 - 5ms/epoch - 5ms/step
# Epoch 193/200
# 1/1 - 0s - loss: 0.0442 - binary_accuracy: 1.0000 - 6ms/epoch - 6ms/step
# Epoch 194/200
# 1/1 - 0s - loss: 0.0436 - binary_accuracy: 1.0000 - 6ms/epoch - 6ms/step
# Epoch 195/200
# 1/1 - 0s - loss: 0.0431 - binary_accuracy: 1.0000 - 5ms/epoch - 5ms/step
# Epoch 196/200
# 1/1 - 0s - loss: 0.0426 - binary_accuracy: 1.0000 - 6ms/epoch - 6ms/step
# Epoch 197/200
# 1/1 - 0s - loss: 0.0421 - binary_accuracy: 1.0000 - 5ms/epoch - 5ms/step
# Epoch 198/200
# 1/1 - 0s - loss: 0.0416 - binary_accuracy: 1.0000 - 5ms/epoch - 5ms/step
# Epoch 199/200
# 1/1 - 0s - loss: 0.0411 - binary_accuracy: 1.0000 - 5ms/epoch - 5ms/step
# Epoch 200/200
# 1/1 - 0s - loss: 0.0406 - binary_accuracy: 1.0000 - 5ms/epoch - 5ms/step

# %%
# 5. 학습과정 보기 및 평가
hist.history.keys()
# Out:
# dict_keys(['loss', 'binary_accuracy'])

# %%
fig, loss_ax = plt.subplots(figsize=(10,5))
loss_ax.plot(hist.history['loss'], 'b', label='loss')
acc_ax = loss_ax.twinx() # loss_ax 와 x축을 공유하는 acc_ax
acc_ax.plot(hist.history['binary_accuracy'], 'r', label='accuracy')

loss_ax.set_xlabel('epoch')
loss_ax.set_ylabel('loss')
acc_ax.set_ylabel('binary_accuracy')

loss_ax.legend(loc='center right')
acc_ax.legend()

plt.show()

# %%
# 모델 평가하기
score = model.evaluate(x_data, y_data)
print('loss :', score[0])
print('accuracy :', score[1])
# Out:
# 1/1 [==============================] - 0s 28ms/step - loss: 0.0401 - binary_accuracy: 1.0000
# loss : 0.040099628269672394
# accuracy : 1.0

# %%
# 예측
int(model.predict(np.array([[0, 1]])).round())
# Out:
# 1/1 [==============================] - 0s 22ms/step
# 1

# %%
# 리스트에 0과 1만 들어 있는지 여부
temp = [0,1,2]
print(all([x in (0,1) for x in temp]))
print(all(x in (0,1) for x in temp))
# Out:
# False
# False

# %%
# 독립변수 2개 (0 0, 0 1, 1 0, 1 1)를 입력받아 예측값을 출력(종료는 수를 1개만 입력할 때)
while True:
    input_str = input('space로 분리해서 0또는 1을 2개 입력하세요(1개만 입력시 종료됩니다)')
    input_list = input_str.strip().split()
    input_nums = list(map(int, input_list))
    if len(input_nums)==1:
        print('데이터를 하나만 입력 하셔서 종료됩니다')
        break
    if all(x in (0,1) for x in input_nums):
        input_data = np.array(input_nums[:2]).reshape(-1, 2)
        print('입력값 :', input_nums[0], input_nums[1])
        print('예측값 :', int(model.predict(input_data).round()))
    else:
        print('0과 1만 입력하셔야 예측값을 볼 수 있습니다.')
# Out:
# space로 분리해서 0또는 1을 2개 입력하세요(1개만 입력시 종료됩니다)0 0
# 입력값 : 0 0
# 1/1 [==============================] - 0s 19ms/step
# 예측값 : 0
# space로 분리해서 0또는 1을 2개 입력하세요(1개만 입력시 종료됩니다)1 1
# 입력값 : 1 1
# 1/1 [==============================] - 0s 19ms/step
# 예측값 : 0
# space로 분리해서 0또는 1을 2개 입력하세요(1개만 입력시 종료됩니다)0 1
# 입력값 : 0 1
# 1/1 [==============================] - 0s 19ms/step
# 예측값 : 1
# space로 분리해서 0또는 1을 2개 입력하세요(1개만 입력시 종료됩니다)2
# 데이터를 하나만 입력 하셔서 종료됩니다

# %% [markdown]
# # 2. AND

# %%
# 1. dataset
X_data = np.array([[0,0],
                  [0,1],
                  [1,1],
                  [1,0]])
Y_data = np.array([[0],
                   [0],
                  [1],
                  [0]])

model = Sequential()
model.add(Dense(units=10,
               input_dim=2,
               activation='relu'))
model.add(Dense(units=20,
               activation='relu'))
model.add(Dense(units=1,
               activation='sigmoid'))

model.compile(loss='binary_crossentropy', 
              optimizer='adam', 
              metrics=['binary_accuracy'])
hist = model.fit(X_data, Y_data,
                epochs=200,
                verbose=2)

fig, loss_ax = plt.subplots(figsize=(10,5))
loss_ax.plot(hist.history['loss'], 'b', label='loss')
acc_ax = loss_ax.twinx() 
acc_ax.plot(hist.history['binary_accuracy'], 'r', label='accuracy')

loss_ax.set_xlabel('epoch')
loss_ax.set_ylabel('loss')
acc_ax.set_ylabel('binary_accuracy')

loss_ax.legend(loc='center right')
acc_ax.legend()

plt.show()

score = model.evaluate(X_data, Y_data)
print('loss :', score[1])
print('accuracy :', score[1])

int(model.predict(np.array([[1, 1]])).round())
# Out:
# Epoch 1/200
# 1/1 - 0s - loss: 0.6779 - binary_accuracy: 0.7500 - 464ms/epoch - 464ms/step
# Epoch 2/200
# 1/1 - 0s - loss: 0.6764 - binary_accuracy: 0.7500 - 6ms/epoch - 6ms/step
# Epoch 3/200
# 1/1 - 0s - loss: 0.6747 - binary_accuracy: 0.7500 - 8ms/epoch - 8ms/step
# Epoch 4/200
# 1/1 - 0s - loss: 0.6731 - binary_accuracy: 0.7500 - 8ms/epoch - 8ms/step
# Epoch 5/200
# 1/1 - 0s - loss: 0.6715 - binary_accuracy: 0.7500 - 7ms/epoch - 7ms/step
# Epoch 6/200
# 1/1 - 0s - loss: 0.6699 - binary_accuracy: 0.7500 - 6ms/epoch - 6ms/step
# Epoch 7/200
# 1/1 - 0s - loss: 0.6683 - binary_accuracy: 0.7500 - 9ms/epoch - 9ms/step
# Epoch 8/200
# 1/1 - 0s - loss: 0.6667 - binary_accuracy: 0.7500 - 9ms/epoch - 9ms/step
# Epoch 9/200
# 1/1 - 0s - loss: 0.6651 - binary_accuracy: 0.7500 - 6ms/epoch - 6ms/step
# Epoch 10/200
# 1/1 - 0s - loss: 0.6635 - binary_accuracy: 0.7500 - 6ms/epoch - 6ms/step
# Epoch 11/200
# 1/1 - 0s - loss: 0.6619 - binary_accuracy: 0.7500 - 9ms/epoch - 9ms/step
# Epoch 12/200
# 1/1 - 0s - loss: 0.6603 - binary_accuracy: 0.7500 - 5ms/epoch - 5ms/step
# Epoch 13/200
# 1/1 - 0s - loss: 0.6586 - binary_accuracy: 0.7500 - 5ms/epoch - 5ms/step
# Epoch 14/200
# 1/1 - 0s - loss: 0.6570 - binary_accuracy: 0.7500 - 9ms/epoch - 9ms/step
# Epoch 15/200
# 1/1 - 0s - loss: 0.6554 - binary_accuracy: 0.7500 - 4ms/epoch - 4ms/step
# Epoch 16/200
# 1/1 - 0s - loss: 0.6537 - binary_accuracy: 0.7500 - 6ms/epoch - 6ms/step
# Epoch 17/200
# 1/1 - 0s - loss: 0.6521 - binary_accuracy: 0.7500 - 5ms/epoch - 5ms/step
# Epoch 18/200
# 1/1 - 0s - loss: 0.6505 - binary_accuracy: 0.7500 - 7ms/epoch - 7ms/step
# Epoch 19/200
# 1/1 - 0s - loss: 0.6488 - binary_accuracy: 0.7500 - 9ms/epoch - 9ms/step
# Epoch 20/200
# 1/1 - 0s - loss: 0.6472 - binary_accuracy: 0.7500 - 5ms/epoch - 5ms/step
# Epoch 21/200
# 1/1 - 0s - loss: 0.6455 - binary_accuracy: 0.7500 - 5ms/epoch - 5ms/step
# Epoch 22/200
# 1/1 - 0s - loss: 0.6439 - binary_accuracy: 0.7500 - 5ms/epoch - 5ms/step
# Epoch 23/200
# 1/1 - 0s - loss: 0.6422 - binary_accuracy: 0.7500 - 5ms/epoch - 5ms/step
# Epoch 24/200
# 1/1 - 0s - loss: 0.6405 - binary_accuracy: 0.7500 - 8ms/epoch - 8ms/step
# Epoch 25/200
# 1/1 - 0s - loss: 0.6388 - binary_accuracy: 0.7500 - 9ms/epoch - 9ms/step
# Epoch 26/200
# 1/1 - 0s - loss: 0.6372 - binary_accuracy: 0.7500 - 5ms/epoch - 5ms/step
# Epoch 27/200
# 1/1 - 0s - loss: 0.6355 - binary_accuracy: 0.7500 - 9ms/epoch - 9ms/step
# Epoch 28/200
# 1/1 - 0s - loss: 0.6338 - binary_accuracy: 0.7500 - 8ms/epoch - 8ms/step
# Epoch 29/200
# 1/1 - 0s - loss: 0.6321 - binary_accuracy: 0.7500 - 12ms/epoch - 12ms/step
# Epoch 30/200
# 1/1 - 0s - loss: 0.6304 - binary_accuracy: 0.7500 - 6ms/epoch - 6ms/step
# Epoch 31/200
# 1/1 - 0s - loss: 0.6286 - binary_accuracy: 0.7500 - 6ms/epoch - 6ms/step
# Epoch 32/200
# 1/1 - 0s - loss: 0.6269 - binary_accuracy: 0.7500 - 9ms/epoch - 9ms/step
# Epoch 33/200
# 1/1 - 0s - loss: 0.6252 - binary_accuracy: 0.7500 - 6ms/epoch - 6ms/step
# Epoch 34/200
# 1/1 - 0s - loss: 0.6235 - binary_accuracy: 0.7500 - 8ms/epoch - 8ms/step
# Epoch 35/200
# 1/1 - 0s - loss: 0.6217 - binary_accuracy: 0.7500 - 5ms/epoch - 5ms/step
# Epoch 36/200
# 1/1 - 0s - loss: 0.6200 - binary_accuracy: 0.7500 - 5ms/epoch - 5ms/step
# Epoch 37/200
# 1/1 - 0s - loss: 0.6182 - binary_accuracy: 0.7500 - 8ms/epoch - 8ms/step
# Epoch 38/200
# 1/1 - 0s - loss: 0.6164 - binary_accuracy: 0.7500 - 8ms/epoch - 8ms/step
# Epoch 39/200
# 1/1 - 0s - loss: 0.6147 - binary_accuracy: 0.7500 - 5ms/epoch - 5ms/step
# Epoch 40/200
# 1/1 - 0s - loss: 0.6129 - binary_accuracy: 0.7500 - 6ms/epoch - 6ms/step
# Epoch 41/200
# 1/1 - 0s - loss: 0.6110 - binary_accuracy: 0.7500 - 4ms/epoch - 4ms/step
# Epoch 42/200
# 1/1 - 0s - loss: 0.6092 - binary_accuracy: 0.7500 - 8ms/epoch - 8ms/step
# Epoch 43/200
# 1/1 - 0s - loss: 0.6074 - binary_accuracy: 0.7500 - 5ms/epoch - 5ms/step
# Epoch 44/200
# 1/1 - 0s - loss: 0.6055 - binary_accuracy: 0.7500 - 6ms/epoch - 6ms/step
# Epoch 45/200
# 1/1 - 0s - loss: 0.6036 - binary_accuracy: 0.7500 - 5ms/epoch - 5ms/step
# Epoch 46/200
# 1/1 - 0s - loss: 0.6018 - binary_accuracy: 0.7500 - 6ms/epoch - 6ms/step
# Epoch 47/200
# 1/1 - 0s - loss: 0.5999 - binary_accuracy: 0.7500 - 5ms/epoch - 5ms/step
# Epoch 48/200
# 1/1 - 0s - loss: 0.5979 - binary_accuracy: 0.7500 - 4ms/epoch - 4ms/step
# Epoch 49/200
# 1/1 - 0s - loss: 0.5960 - binary_accuracy: 0.7500 - 4ms/epoch - 4ms/step
# Epoch 50/200
# 1/1 - 0s - loss: 0.5941 - binary_accuracy: 0.7500 - 6ms/epoch - 6ms/step
# Epoch 51/200
# 1/1 - 0s - loss: 0.5921 - binary_accuracy: 0.7500 - 8ms/epoch - 8ms/step
# Epoch 52/200
# 1/1 - 0s - loss: 0.5902 - binary_accuracy: 0.7500 - 4ms/epoch - 4ms/step
# Epoch 53/200
# 1/1 - 0s - loss: 0.5883 - binary_accuracy: 0.7500 - 8ms/epoch - 8ms/step
# Epoch 54/200
# 1/1 - 0s - loss: 0.5863 - binary_accuracy: 0.7500 - 5ms/epoch - 5ms/step
# Epoch 55/200
# 1/1 - 0s - loss: 0.5844 - binary_accuracy: 0.7500 - 7ms/epoch - 7ms/step
# Epoch 56/200
# 1/1 - 0s - loss: 0.5824 - binary_accuracy: 0.7500 - 5ms/epoch - 5ms/step
# Epoch 57/200
# 1/1 - 0s - loss: 0.5804 - binary_accuracy: 0.7500 - 7ms/epoch - 7ms/step
# Epoch 58/200
# 1/1 - 0s - loss: 0.5784 - binary_accuracy: 0.7500 - 6ms/epoch - 6ms/step
# Epoch 59/200
# 1/1 - 0s - loss: 0.5764 - binary_accuracy: 0.7500 - 8ms/epoch - 8ms/step
# Epoch 60/200
# 1/1 - 0s - loss: 0.5744 - binary_accuracy: 0.7500 - 9ms/epoch - 9ms/step
# Epoch 61/200
# 1/1 - 0s - loss: 0.5723 - binary_accuracy: 0.7500 - 5ms/epoch - 5ms/step
# Epoch 62/200
# 1/1 - 0s - loss: 0.5702 - binary_accuracy: 0.7500 - 11ms/epoch - 11ms/step
# Epoch 63/200
# 1/1 - 0s - loss: 0.5682 - binary_accuracy: 0.7500 - 7ms/epoch - 7ms/step
# Epoch 64/200
# 1/1 - 0s - loss: 0.5660 - binary_accuracy: 0.7500 - 6ms/epoch - 6ms/step
# Epoch 65/200
# 1/1 - 0s - loss: 0.5637 - binary_accuracy: 0.7500 - 5ms/epoch - 5ms/step
# Epoch 66/200
# 1/1 - 0s - loss: 0.5615 - binary_accuracy: 0.7500 - 8ms/epoch - 8ms/step
# Epoch 67/200
# 1/1 - 0s - loss: 0.5592 - binary_accuracy: 0.7500 - 9ms/epoch - 9ms/step
# Epoch 68/200
# 1/1 - 0s - loss: 0.5569 - binary_accuracy: 0.7500 - 7ms/epoch - 7ms/step
# Epoch 69/200
# 1/1 - 0s - loss: 0.5546 - binary_accuracy: 0.7500 - 5ms/epoch - 5ms/step
# Epoch 70/200
# 1/1 - 0s - loss: 0.5523 - binary_accuracy: 0.7500 - 9ms/epoch - 9ms/step
# Epoch 71/200
# 1/1 - 0s - loss: 0.5499 - binary_accuracy: 0.7500 - 9ms/epoch - 9ms/step
# Epoch 72/200
# 1/1 - 0s - loss: 0.5475 - binary_accuracy: 0.7500 - 7ms/epoch - 7ms/step
# Epoch 73/200
# 1/1 - 0s - loss: 0.5452 - binary_accuracy: 0.7500 - 8ms/epoch - 8ms/step
# Epoch 74/200
# 1/1 - 0s - loss: 0.5429 - binary_accuracy: 0.7500 - 5ms/epoch - 5ms/step
# Epoch 75/200
# 1/1 - 0s - loss: 0.5406 - binary_accuracy: 0.7500 - 7ms/epoch - 7ms/step
# Epoch 76/200
# 1/1 - 0s - loss: 0.5382 - binary_accuracy: 0.7500 - 8ms/epoch - 8ms/step
# Epoch 77/200
# 1/1 - 0s - loss: 0.5358 - binary_accuracy: 0.7500 - 5ms/epoch - 5ms/step
# Epoch 78/200
# 1/1 - 0s - loss: 0.5333 - binary_accuracy: 0.7500 - 7ms/epoch - 7ms/step
# Epoch 79/200
# 1/1 - 0s - loss: 0.5307 - binary_accuracy: 0.7500 - 8ms/epoch - 8ms/step
# Epoch 80/200
# 1/1 - 0s - loss: 0.5281 - binary_accuracy: 0.7500 - 5ms/epoch - 5ms/step
# Epoch 81/200
# 1/1 - 0s - loss: 0.5255 - binary_accuracy: 0.7500 - 5ms/epoch - 5ms/step
# Epoch 82/200
# 1/1 - 0s - loss: 0.5229 - binary_accuracy: 0.7500 - 6ms/epoch - 6ms/step
# Epoch 83/200
# 1/1 - 0s - loss: 0.5202 - binary_accuracy: 0.7500 - 6ms/epoch - 6ms/step
# Epoch 84/200
# 1/1 - 0s - loss: 0.5176 - binary_accuracy: 0.7500 - 8ms/epoch - 8ms/step
# Epoch 85/200
# 1/1 - 0s - loss: 0.5150 - binary_accuracy: 0.7500 - 7ms/epoch - 7ms/step
# Epoch 86/200
# 1/1 - 0s - loss: 0.5123 - binary_accuracy: 0.7500 - 6ms/epoch - 6ms/step
# Epoch 87/200
# 1/1 - 0s - loss: 0.5096 - binary_accuracy: 0.7500 - 5ms/epoch - 5ms/step
# Epoch 88/200
# 1/1 - 0s - loss: 0.5069 - binary_accuracy: 0.7500 - 5ms/epoch - 5ms/step
# Epoch 89/200
# 1/1 - 0s - loss: 0.5043 - binary_accuracy: 0.7500 - 5ms/epoch - 5ms/step
# Epoch 90/200
# 1/1 - 0s - loss: 0.5016 - binary_accuracy: 0.7500 - 5ms/epoch - 5ms/step
# Epoch 91/200
# 1/1 - 0s - loss: 0.4990 - binary_accuracy: 0.7500 - 7ms/epoch - 7ms/step
# Epoch 92/200
# 1/1 - 0s - loss: 0.4961 - binary_accuracy: 0.7500 - 6ms/epoch - 6ms/step
# Epoch