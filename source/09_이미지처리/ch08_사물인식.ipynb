# %% [markdown]
# YoloV8
# - https://docs.ultralytics.com/ko

# %% [markdown]
# # 1. Yolov8을 위한 패키지 설치 및 import

# %%
! pip install ultralytics
# Out:
# Collecting ultralytics
#   Downloading ultralytics-8.3.55-py3-none-any.whl (904 kB)
#      ------------------------------------- 904.3/904.3 kB 14.2 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.23.0 in c:\users\4545\anaconda3\lib\site-packages (from ultralytics) (1.23.5)
# Collecting ultralytics-thop>=2.0.0
#   Downloading ultralytics_thop-2.0.13-py3-none-any.whl (26 kB)
# Requirement already satisfied: tqdm>=4.64.0 in c:\users\4545\anaconda3\lib\site-packages (from ultralytics) (4.64.1)
# Requirement already satisfied: opencv-python>=4.6.0 in c:\users\4545\anaconda3\lib\site-packages (from ultralytics) (4.10.0.84)
# Requirement already satisfied: scipy>=1.4.1 in c:\users\4545\anaconda3\lib\site-packages (from ultralytics) (1.10.0)
# Requirement already satisfied: pillow>=7.1.2 in c:\users\4545\anaconda3\lib\site-packages (from ultralytics) (9.4.0)
# Requirement already satisfied: pyyaml>=5.3.1 in c:\users\4545\anaconda3\lib\site-packages (from ultralytics) (6.0)
# Requirement already satisfied: torch!=2.4.0,>=1.8.0 in c:\users\4545\anaconda3\lib\site-packages (from ultralytics) (1.12.1)
# Requirement already satisfied: requests>=2.23.0 in c:\users\4545\anaconda3\lib\site-packages (from ultralytics) (2.28.1)
# Requirement already satisfied: pandas>=1.1.4 in c:\users\4545\anaconda3\lib\site-packages (from ultralytics) (1.5.3)
# Requirement already satisfied: seaborn>=0.11.0 in c:\users\4545\anaconda3\lib\site-packages (from ultralytics) (0.12.2)
# Requirement already satisfied: psutil in c:\users\4545\anaconda3\lib\site-packages (from ultralytics) (5.9.0)
# Requirement already satisfied: matplotlib>=3.3.0 in c:\users\4545\anaconda3\lib\site-packages (from ultralytics) (3.7.0)
# Collecting torchvision>=0.9.0
#   Downloading torchvision-0.20.1-cp310-cp310-win_amd64.whl (1.6 MB)
#      ---------------------------------------- 1.6/1.6 MB 19.6 MB/s eta 0:00:00
# Collecting py-cpuinfo
#   Downloading py_cpuinfo-9.0.0-py3-none-any.whl (22 kB)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\4545\anaconda3\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (4.25.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\4545\anaconda3\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (1.0.5)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\4545\anaconda3\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (3.0.9)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\4545\anaconda3\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\4545\anaconda3\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (22.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\4545\anaconda3\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (2.8.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\4545\anaconda3\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (0.11.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\4545\anaconda3\lib\site-packages (from pandas>=1.1.4->ultralytics) (2022.7)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\4545\anaconda3\lib\site-packages (from requests>=2.23.0->ultralytics) (3.4)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\4545\anaconda3\lib\site-packages (from requests>=2.23.0->ultralytics) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\4545\anaconda3\lib\site-packages (from requests>=2.23.0->ultralytics) (2024.8.30)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\4545\anaconda3\lib\site-packages (from requests>=2.23.0->ultralytics) (1.26.14)
# Requirement already satisfied: typing_extensions in c:\users\4545\anaconda3\lib\site-packages (from torch!=2.4.0,>=1.8.0->ultralytics) (4.12.2)
# Collecting torch!=2.4.0,>=1.8.0
#   Downloading torch-2.5.1-cp310-cp310-win_amd64.whl (203.1 MB)
#      -------------------------------------- 203.1/203.1 MB 6.9 MB/s eta 0:00:00
# Requirement already satisfied: networkx in c:\users\4545\anaconda3\lib\site-packages (from torch!=2.4.0,>=1.8.0->ultralytics) (2.8.4)
# Requirement already satisfied: filelock in c:\users\4545\anaconda3\lib\site-packages (from torch!=2.4.0,>=1.8.0->ultralytics) (3.9.0)
# Requirement already satisfied: jinja2 in c:\users\4545\anaconda3\lib\site-packages (from torch!=2.4.0,>=1.8.0->ultralytics) (3.1.2)
# Collecting sympy==1.13.1
#   Downloading sympy-1.13.1-py3-none-any.whl (6.2 MB)
#      ---------------------------------------- 6.2/6.2 MB 26.3 MB/s eta 0:00:00
# Requirement already satisfied: fsspec in c:\users\4545\anaconda3\lib\site-packages (from torch!=2.4.0,>=1.8.0->ultralytics) (2022.11.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\4545\anaconda3\lib\site-packages (from sympy==1.13.1->torch!=2.4.0,>=1.8.0->ultralytics) (1.2.1)
# Requirement already satisfied: colorama in c:\users\4545\anaconda3\lib\site-packages (from tqdm>=4.64.0->ultralytics) (0.4.6)
# Requirement already satisfied: six>=1.5 in c:\users\4545\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\4545\anaconda3\lib\site-packages (from jinja2->torch!=2.4.0,>=1.8.0->ultralytics) (2.1.1)
# Installing collected packages: py-cpuinfo, sympy, torch, ultralytics-thop, torchvision, ultralytics
#   Attempting uninstall: sympy
#     Found existing installation: sympy 1.11.1
#     Uninstalling sympy-1.11.1:
#       Successfully uninstalled sympy-1.11.1
#   Attempting uninstall: torch
#     Found existing installation: torch 1.12.1
#     Uninstalling torch-1.12.1:
#       Successfully uninstalled torch-1.12.1
# Successfully installed py-cpuinfo-9.0.0 sympy-1.13.1 torch-2.5.1 torchvision-0.20.1 ultralytics-8.3.55 ultralytics-thop-2.0.13

# %%
! pip show ultralytics
# Out:
# Name: ultralytics
# Version: 8.3.55
# --- Logging error ---
# Traceback (most recent call last):
#   File "C:\Users\4545\anaconda3\lib\site-packages\pip\_internal\utils\logging.py", line 177, in emit
#     self.console.print(renderable, overflow="ignore", crop=False, style=style)
#   File "C:\Users\4545\anaconda3\lib\site-packages\pip\_vendor\rich\console.py", line 1646, in print
#     with self:
#   File "C:\Users\4545\anaconda3\lib\site-packages\pip\_vendor\rich\console.py", line 848, in __exit__
#     self._exit_buffer()
#   File "C:\Users\4545\anaconda3\lib\site-packages\pip\_vendor\rich\console.py", line 806, in _exit_buffer
#     self._check_buffer()
#   File "C:\Users\4545\anaconda3\lib\site-packages\pip\_vendor\rich\console.py", line 1999, in _check_buffer
#     legacy_windows_render(
#   File "C:\Users\4545\anaconda3\lib\site-packages\pip\_vendor\rich\_windows_renderer.py", line 19, in legacy_windows_render
#     term.write_text(text)
#   File "C:\Users\4545\anaconda3\lib\site-packages\pip\_vendor\rich\_win32_console.py", line 403, in write_text
#     self.write(text)
# UnicodeEncodeError: 'cp949' codec can't encode character '\U0001f680' in position 26: illegal multibyte sequence
# Call stack:
#   File "C:\Users\4545\anaconda3\Scripts\pip-script.py", line 10, in <module>
#     sys.exit(main())
#   File "C:\Users\4545\anaconda3\lib\site-packages\pip\_internal\cli\main.py", line 70, in main
#     return command.main(cmd_args)
#   File "C:\Users\4545\anaconda3\lib\site-packages\pip\_internal\cli\base_command.py", line 101, in main
#     return self._main(args)
#   File "C:\Users\4545\anaconda3\lib\site-packages\pip\_internal\cli\base_command.py", line 214, in _main
#     return run(options, args)
#   File "C:\Users\4545\anaconda3\lib\site-packages\pip\_internal\cli\base_command.py", line 160, in exc_logging_wrapper
#     status = run_func(*args)
#   File "C:\Users\4545\anaconda3\lib\site-packages\pip\_internal\commands\show.py", line 45, in run
#     if not print_results(
#   File "C:\Users\4545\anaconda3\lib\site-packages\pip\_internal\commands\show.py", line 155, in print_results
#     write_output("Summary: %s", dist.summary)
#   File "C:\Users\4545\anaconda3\lib\site-packages\pip\_internal\utils\misc.py", line 336, in write_output
#     logger.info(msg, *args)
#   File "C:\Users\4545\anaconda3\lib\logging\__init__.py", line 1477, in info
#     self._log(INFO, msg, args, **kwargs)
#   File "C:\Users\4545\anaconda3\lib\logging\__init__.py", line 1624, in _log
#     self.handle(record)
#   File "C:\Users\4545\anaconda3\lib\logging\__init__.py", line 1634, in handle
#     self.callHandlers(record)
#   File "C:\Users\4545\anaconda3\lib\logging\__init__.py", line 1696, in callHandlers
#     hdlr.handle(record)
#   File "C:\Users\4545\anaconda3\lib\logging\__init__.py", line 968, in handle
#     self.emit(record)
#   File "C:\Users\4545\anaconda3\lib\site-packages\pip\_internal\utils\logging.py", line 179, in emit
#     self.handleError(record)
# Message: 'Summary: %s'
# Arguments: ('Ultralytics YOLO \U0001f680 for SOTA object detection, multi-object tracking, instance segmentation, pose estimation and image classification.',)
# --- Logging error ---
# Traceback (most recent call last):
#   File "C:\Users\4545\anaconda3\lib\site-packages\pip\_internal\utils\logging.py", line 177, in emit
#     self.console.print(renderable, overflow="ignore", crop=False, style=style)
#   File "C:\Users\4545\anaconda3\lib\site-packages\pip\_vendor\rich\console.py", line 1646, in print
#     with self:
#   File "C:\Users\4545\anaconda3\lib\site-packages\pip\_vendor\rich\console.py", line 848, in __exit__
#     self._exit_buffer()
#   File "C:\Users\4545\anaconda3\lib\site-packages\pip\_vendor\rich\console.py", line 806, in _exit_buffer
#     self._check_buffer()
#   File "C:\Users\4545\anaconda3\lib\site-packages\pip\_vendor\rich\console.py", line 1999, in _check_buffer
#     legacy_windows_render(
#   File "C:\Users\4545\anaconda3\lib\site-packages\pip\_vendor\rich\_windows_renderer.py", line 19, in legacy_windows_render
#     term.write_text(text)
#   File "C:\Users\4545\anaconda3\lib\site-packages\pip\_vendor\rich\_win32_console.py", line 403, in write_text
#     self.write(text)
# UnicodeEncodeError: 'cp949' codec can't encode character '\U0001f680' in position 26: illegal multibyte sequence
# Call stack:
#   File "C:\Users\4545\anaconda3\Scripts\pip-script.py", line 10, in <module>
#     sys.exit(main())
#   File "C:\Users\4545\anaconda3\lib\site-packages\pip\_internal\cli\main.py", line 70, in main
#     return command.main(cmd_args)
#   File "C:\Users\4545\anaconda3\lib\site-packages\pip\_internal\cli\base_command.py", line 101, in main
#     return self._main(args)
#   File "C:\Users\4545\anaconda3\lib\site-packages\pip\_internal\cli\base_command.py", line 214, in _main
#     return run(options, args)
#   File "C:\Users\4545\anaconda3\lib\site-packages\pip\_internal\cli\base_command.py", line 160, in exc_logging_wrapper
#     status = run_func(*args)
#   File "C:\Users\4545\anaconda3\lib\site-packages\pip\_internal\commands\show.py", line 45, in run
#     if not print_results(
#   File "C:\Users\4545\anaconda3\lib\site-packages\pip\_internal\commands\show.py", line 156, in print_results
#     write_output("Home-page: %s", dist.homepage)
#   File "C:\Users\4545\anaconda3\lib\site-packages\pip\_internal\utils\misc.py", line 336, in write_output
#     logger.info(msg, *args)
#   File "C:\Users\4545\anaconda3\lib\logging\__init__.py", line 1477, in info
#     self._log(INFO, msg, args, **kwargs)
#   File "C:\Users\4545\anaconda3\lib\logging\__init__.py", line 1624, in _log
#     self.handle(record)
#   File "C:\Users\4545\anaconda3\lib\logging\__init__.py", line 1634, in handle
#     self.callHandlers(record)
#   File "C:\Users\4545\anaconda3\lib\logging\__init__.py", line 1696, in callHandlers
#     hdlr.handle(record)
#   File "C:\Users\4545\anaconda3\lib\logging\__init__.py", line 968, in handle
#     self.emit(record)
#   File "C:\Users\4545\anaconda3\lib\site-packages\pip\_internal\utils\logging.py", line 179, in emit
#     self.handleError(record)
# Message: 'Home-page: %s'
# Arguments: ('',)
# --- Logging error ---
# Traceback (most recent call last):
#   File "C:\Users\4545\anaconda3\lib\site-packages\pip\_internal\utils\logging.py", line 177, in emit
#     self.console.print(renderable, overflow="ignore", crop=False, style=style)
#   File "C:\Users\4545\anaconda3\lib\site-packages\pip\_vendor\rich\console.py", line 1646, in print
#     with self:
#   File "C:\Users\4545\anaconda3\lib\site-packages\pip\_vendor\rich\console.py", line 848, in __exit__
#     self._exit_buffer()
#   File "C:\Users\4545\anaconda3\lib\site-packages\pip\_vendor\rich\console.py", line 806, in _exit_buffer
#     self._check_buffer()
#   File "C:\Users\4545\anaconda3\lib\site-packages\pip\_vendor\rich\console.py", line 1999, in _check_buffer
#     legacy_windows_render(
#   File "C:\Users\4545\anaconda3\lib\site-packages\pip\_vendor\rich\_windows_renderer.py", line 19, in legacy_windows_render
#     term.write_text(text)
#   File "C:\Users\4545\anaconda3\lib\site-packages\pip\_vendor\rich\_win32_console.py", line 403, in write_text
#     self.write(text)
# UnicodeEncodeError: 'cp949' codec can't encode character '\U0001f680' in position 26: illegal multibyte sequence
# Call stack:
#   File "C:\Users\4545\anaconda3\Scripts\pip-script.py", line 10, in <module>
#     sys.exit(main())
#   File "C:\Users\4545\anaconda3\lib\site-packages\pip\_internal\cli\main.py", line 70, in main
#     return command.main(cmd_args)
#   File "C:\Users\4545\anaconda3\lib\site-packages\pip\_internal\cli\base_command.py", line 101, in main
#     return self._main(args)
#   File "C:\Users\4545\anaconda3\lib\site-packages\pip\_internal\cli\base_command.py", line 214, in _main
#     return run(options, args)
#   File "C:\Users\4545\anaconda3\lib\site-packages\pip\_internal\cli\base_command.py", line 160, in exc_logging_wrapper
#     status = run_func(*args)
#   File "C:\Users\4545\anaconda3\lib\site-packages\pip\_internal\commands\show.py", line 45, in run
#     if not print_results(
#   File "C:\Users\4545\anaconda3\lib\site-packages\pip\_internal\commands\show.py", line 157, in print_results
#     write_output("Author: %s", dist.author)
#   File "C:\Users\4545\anaconda3\lib\site-packages\pip\_internal\utils\misc.py", line 336, in write_output
#     logger.info(msg, *args)
#   File "C:\Users\4545\anaconda3\lib\logging\__init__.py", line 1477, in info
#     self._log(INFO, msg, args, **kwargs)
#   File "C:\Users\4545\anaconda3\lib\logging\__init__.py", line 1624, in _log
#     self.handle(record)
#   File "C:\Users\4545\anaconda3\lib\logging\__init__.py", line 1634, in handle
#     self.callHandlers(record)
#   File "C:\Users\4545\anaconda3\lib\logging\__init__.py", line 1696, in callHandlers
#     hdlr.handle(record)
#   File "C:\Users\4545\anaconda3\lib\logging\__init__.py", line 968, in handle
#     self.emit(record)
#   File "C:\Users\4545\anaconda3\lib\site-packages\pip\_internal\utils\logging.py", line 179, in emit
#     self.handleError(record)
# Message: 'Author: %s'
# Arguments: ('',)
# --- Logging error ---
# Traceback (most recent call last):
#   File "C:\Users\4545\anaconda3\lib\site-packages\pip\_internal\utils\logging.py", line 177, in emit
#     self.console.print(renderable, overflow="ignore", crop=False, style=style)
#   File "C:\Users\4545\anaconda3\lib\site-packages\pip\_vendor\rich\console.py", line 1646, in print
#     with self:
#   File "C:\Users\4545\anaconda3\lib\site-packages\pip\_vendor\rich\console.py", line 848, in __exit__
#     self._exit_buffer()
#   File "C:\Users\4545\anaconda3\lib\site-packages\pip\_vendor\rich\console.py", line 806, in _exit_buffer
#     self._check_buffer()
#   File "C:\Users\4545\anaconda3\lib\site-packages\pip\_vendor\rich\console.py", line 1999, in _check_buffer
#     legacy_windows_render(
#   File "C:\Users\4545\anaconda3\lib\site-packages\pip\_vendor\rich\_windows_renderer.py", line 19, in legacy_windows_render
#     term.write_text(text)
#   File "C:\Users\4545\anaconda3\lib\site-packages\pip\_vendor\rich\_win32_console.py", line 403, in write_text
#     self.write(text)
# UnicodeEncodeError: 'cp949' codec can't encode character '\U0001f680' in position 26: illegal multibyte sequence
# Call stack:
#   File "C:\Users\4545\anaconda3\Scripts\pip-script.py", line 10, in <module>
#     sys.exit(main())
#   File "C:\Users\4545\anaconda3\lib\site-packages\pip\_internal\cli\main.py", line 70, in main
#     return command.main(cmd_args)
#   File "C:\Users\4545\anaconda3\lib\site-packages\pip\_internal\cli\base_command.py", line 101, in main
#     return self._main(args)
#   File "C:\Users\4545\anaconda3\lib\site-packages\pip\_internal\cli\base_command.py", line 214, in _main
#     return run(options, args)
#   File "C:\Users\4545\anaconda3\lib\site-packages\pip\_internal\cli\base_command.py", line 160, in exc_logging_wrapper
#     status = run_func(*args)
#   File "C:\Users\4545\anaconda3\lib\site-packages\pip\_internal\commands\show.py", line 45, in run
#     if not print_results(
#   File "C:\Users\4545\anaconda3\lib\site-packages\pip\_internal\commands\show.py", line 158, in print_results
#     write_output("Author-email: %s", dist.author_email)
#   File "C:\Users\4545\anaconda3\lib\site-packages\pip\_internal\utils\misc.py", line 336, in write_output
#     logger.info(msg, *args)
#   File "C:\Users\4545\anaconda3\lib\logging\__init__.py", line 1477, in info
#     self._log(INFO, msg, args, **kwargs)
#   File "C:\Users\4545\anaconda3\lib\logging\__init__.py", line 1624, in _log
#     self.handle(record)
#   File "C:\Users\4545\anaconda3\lib\logging\__init__.py", line 1634, in handle
#     self.callHandlers(record)
#   File "C:\Users\4545\anaconda3\lib\logging\__init__.py", line 1696, in callHandlers
#     hdlr.handle(record)
#   File "C:\Users\4545\anaconda3\lib\logging\__init__.py", line 968, in handle
#     self.emit(record)
#   File "C:\Users\4545\anaconda3\lib\site-packages\pip\_internal\utils\logging.py", line 179, in emit
#     self.handleError(record)
# Message: 'Author-email: %s'
# Arguments: ('Glenn Jocher <glenn.jocher@ultralytics.com>, Jing Qiu <jing.qiu@ultralytics.com>',)
# --- Logging error ---
# Traceback (most recent call last):
#   File "C:\Users\4545\anaconda3\lib\site-packages\pip\_internal\utils\logging.py", line 177, in emit
#     self.console.print(renderable, overflow="ignore", crop=False, style=style)
#   File "C:\Users\4545\anaconda3\lib\site-packages\pip\_vendor\rich\console.py", line 1646, in print
#     with self:
#   File "C:\Users\4545\anaconda3\lib\site-packages\pip\_vendor\rich\console.py", line 848, in __exit__
#     self._exit_buffer()
#   File "C:\Users\4545\anaconda3\lib\site-packages\pip\_vendor\rich\console.py", line 806, in _exit_buffer
#     self._check_buffer()
#   File "C:\Users\4545\anaconda3\lib\site-packages\pip\_vendor\rich\console.py", line 1999, in _check_buffer
#     legacy_windows_render(
#   File "C:\Users\4545\anaconda3\lib\site-packages\pip\_vendor\rich\_windows_renderer.py", line 19, in legacy_windows_render
#     term.write_text(text)
#   File "C:\Users\4545\anaconda3\lib\site-packages\pip\_vendor\rich\_win32_console.py", line 403, in write_text
#     self.write(text)
# UnicodeEncodeError: 'cp949' codec can't encode character '\U0001f680' in position 26: illegal multibyte sequence
# Call stack:
#   File "C:\Users\4545\anaconda3\Scripts\pip-script.py", line 10, in <module>
#     sys.exit(main())
#   File "C:\Users\4545\anaconda3\lib\site-packages\pip\_internal\cli\main.py", line 70, in main
#     return command.main(cmd_args)
#   File "C:\Users\4545\anaconda3\lib\site-packages\pip\_internal\cli\base_command.py", line 101, in main
#     return self._main(args)
#   File "C:\Users\4545\anaconda3\lib\site-packages\pip\_internal\cli\base_command.py", line 214, in _main
#     return run(options, args)
#   File "C:\Users\4545\anaconda3\lib\site-packages\pip\_internal\cli\base_command.py", line 160, in exc_logging_wrapper
#     status = run_func(*args)
#   File "C:\Users\4545\anaconda3\lib\site-packages\pip\_internal\commands\show.py", line 45, in run
#     if not print_results(
#   File "C:\Users\4545\anaconda3\lib\site-packages\pip\_internal\commands\show.py", line 159, in print_results
#     write_output("License: %s", dist.license)
#   File "C:\Users\4545\anaconda3\lib\site-packages\pip\_internal\utils\misc.py", line 336, in write_output
#     logger.info(msg, *args)
#   File "C:\Users\4545\anaconda3\lib\logging\__init__.py", line 1477, in info
#     self._log(INFO, msg, args, **kwargs)
#   File "C:\Users\4545\anaconda3\lib\logging\__init__.py", line 1624, in _log
#     self.handle(record)
#   File "C:\Users\4545\anaconda3\lib\logging\__init__.py", line 1634, in handle
#     self.callHandlers(record)
#   File "C:\Users\4545\anaconda3\lib\logging\__init__.py", line 1696, in callHandlers
#     hdlr.handle(record)
#   File "C:\Users\4545\anaconda3\lib\logging\__init__.py", line 968, in handle
#     self.emit(record)
#   File "C:\Users\4545\anaconda3\lib\site-packages\pip\_internal\utils\logging.py", line 179, in emit
#     self.handleError(record)
# Message: 'License: %s'
# Arguments: ('AGPL-3.0',)
# --- Logging error ---
# Traceback (most recent call last):
#   File "C:\Users\4545\anaconda3\lib\site-packages\pip\_internal\utils\logging.py", line 177, in emit
#     self.console.print(renderable, overflow="ignore", crop=False, style=style)
#   File "C:\Users\4545\anaconda3\lib\site-packages\pip\_vendor\rich\console.py", line 1646, in print
#     with self:
#   File "C:\Users\4545\anaconda3\lib\site-packages\pip\_vendor\rich\console.py", line 848, in __exit__
#     self._exit_buffer()
#   File "C:\Users\4545\anaconda3\lib\site-packages\pip\_vendor\rich\console.py", line 806, in _exit_buffer
#     self._check_buffer()
#   File "C:\Users\4545\anaconda3\lib\site-packages\pip\_vendor\rich\console.py", line 1999, in _check_buffer
#     legacy_windows_render(
#   File "C:\Users\4545\anaconda3\lib\site-packages\pip\_vendor\rich\_windows_renderer.py", line 19, in legacy_windows_render
#     term.write_text(text)
#   File "C:\Users\4545\anaconda3\lib\site-packages\pip\_vendor\rich\_win32_console.py", line 403, in write_text
#     self.write(text)
# UnicodeEncodeError: 'cp949' codec can't encode character '\U0001f680' in position 26: illegal multibyte sequence
# Call stack:
#   File "C:\Users\4545\anaconda3\Scripts\pip-script.py", line 10, in <module>
#     sys.exit(main())
#   File "C:\Users\4545\anaconda3\lib\site-packages\pip\_internal\cli\main.py", line 70, in main
#     return command.main(cmd_args)
#   File "C:\Users\4545\anaconda3\lib\site-packages\pip\_internal\cli\base_command.py", line 101, in main
#     return self._main(args)
#   File "C:\Users\4545\anaconda3\lib\site-packages\pip\_internal\cli\base_command.py", line 214, in _main
#     return run(options, args)
#   File "C:\Users\4545\anaconda3\lib\site-packages\pip\_internal\cli\base_command.py", line 160, in exc_logging_wrapper
#     status = run_func(*args)
#   File "C:\Users\4545\anaconda3\lib\site-packages\pip\_internal\commands\show.py", line 45, in run
#     if not print_results(
#   File "C:\Users\4545\anaconda3\lib\site-packages\pip\_internal\commands\show.py", line 160, in print_results
#     write_output("Location: %s", dist.location)
#   File "C:\Users\4545\anaconda3\lib\site-packages\pip\_internal\utils\misc.py", line 336, in write_output
#     logger.info(msg, *args)
#   File "C:\Users\4545\anaconda3\lib\logging\__init__.py", line 1477, in info
#     self._log(INFO, msg, args, **kwargs)
#   File "C:\Users\4545\anaconda3\lib\logging\__init__.py", line 1624, in _log
#     self.handle(record)
#   File "C:\Users\4545\anaconda3\lib\logging\__init__.py", line 1634, in handle
#     self.callHandlers(record)
#   File "C:\Users\4545\anaconda3\lib\logging\__init__.py", line 1696, in callHandlers
#     hdlr.handle(record)
#   File "C:\Users\4545\anaconda3\lib\logging\__init__.py", line 968, in handle
#     self.emit(record)
#   File "C:\Users\4545\anaconda3\lib\site-packages\pip\_internal\utils\logging.py", line 179, in emit
#     self.handleError(record)
# Message: 'Location: %s'
# Arguments: ('c:\\users\\4545\\anaconda3\\lib\\site-packages',)
# --- Logging error ---
# Traceback (most recent call last):
#   File "C:\Users\4545\anaconda3\lib\site-packages\pip\_internal\utils\logging.py", line 177, in emit
#     self.console.print(renderable, overflow="ignore", crop=False, style=style)
#   File "C:\Users\4545\anaconda3\lib\site-packages\pip\_vendor\rich\console.py", line 1646, in print
#     with self:
#   File "C:\Users\4545\anaconda3\lib\site-packages\pip\_vendor\rich\console.py", line 848, in __exit__
#     self._exit_buffer()
#   File "C:\Users\4545\anaconda3\lib\site-packages\pip\_vendor\rich\console.py", line 806, in _exit_buffer
#     self._check_buffer()
#   File "C:\Users\4545\anaconda3\lib\site-packages\pip\_vendor\rich\console.py", line 1999, in _check_buffer
#     legacy_windows_render(
#   File "C:\Users\4545\anaconda3\lib\site-packages\pip\_vendor\rich\_windows_renderer.py", line 19, in legacy_windows_render
#     term.write_text(text)
#   File "C:\Users\4545\anaconda3\lib\site-packages\pip\_vendor\rich\_win32_console.py", line 403, in write_text
#     self.write(text)
# UnicodeEncodeError: 'cp949' codec can't encode character '\U0001f680' in position 26: illegal multibyte sequence
# Call stack:
#   File "C:\Users\4545\anaconda3\Scripts\pip-script.py", line 10, in <module>
#     sys.exit(main())
#   File "C:\Users\4545\anaconda3\lib\site-packages\pip\_internal\cli\main.py", line 70, in main
#     return command.main(cmd_args)
#   File "C:\Users\4545\anaconda3\lib\site-packages\pip\_internal\cli\base_command.py", line 101, in main
#     return self._main(args)
#   File "C:\Users\4545\anaconda3\lib\site-packages\pip\_internal\cli\base_command.py", line 214, in _main
#     return run(options, args)
#   File "C:\Users\4545\anaconda3\lib\site-packages\pip\_internal\cli\base_command.py", line 160, in exc_logging_wrapper
#     status = run_func(*args)
#   File "C:\Users\4545\anaconda3\lib\site-packages\pip\_internal\commands\show.py", line 45, in run
#     if not print_results(
#   File "C:\Users\4545\anaconda3\lib\site-packages\pip\_internal\commands\show.py", line 161, in print_results
#     write_output("Requires: %s", ", ".join(dist.requires))
#   File "C:\Users\4545\anaconda3\lib\site-packages\pip\_internal\utils\misc.py", line 336, in write_output
#     logger.info(msg, *args)
#   File "C:\Users\4545\anaconda3\lib\logging\__init__.py", line 1477, in info
#     self._log(INFO, msg, args, **kwargs)
#   File "C:\Users\4545\anaconda3\lib\logging\__init__.py", line 1624, in _log
#     self.handle(record)
#   File "C:\Users\4545\anaconda3\lib\logging\__init__.py", line 1634, in handle
#     self.callHandlers(record)
#   File "C:\Users\4545\anaconda3\lib\logging\__init__.py", line 1696, in callHandlers
#     hdlr.handle(record)
#   File "C:\Users\4545\anaconda3\lib\logging\__init__.py", line 968, in handle
#     self.emit(record)
#   File "C:\Users\4545\anaconda3\lib\site-packages\pip\_internal\utils\logging.py", line 179, in emit
#     self.handleError(record)
# Message: 'Requires: %s'
# Arguments: ('matplotlib, numpy, opencv-python, pandas, pillow, psutil, py-cpuinfo, pyyaml, requests, scipy, seaborn, torch, torch, torchvision, tqdm, ultralytics-thop',)
# --- Logging error ---
# Traceback (most recent call last):
#   File "C:\Users\4545\anaconda3\lib\site-packages\pip\_internal\utils\logging.py", line 177, in emit
#     self.console.print(renderable, overflow="ignore", crop=False, style=style)
#   File "C:\Users\4545\anaconda3\lib\site-packages\pip\_vendor\rich\console.py", line 1646, in print
#     with self:
#   File "C:\Users\4545\anaconda3\lib\site-packages\pip\_vendor\rich\console.py", line 848, in __exit__
#     self._exit_buffer()
#   File "C:\Users\4545\anaconda3\lib\site-packages\pip\_vendor\rich\console.py", line 806, in _exit_buffer
#     self._check_buffer()
#   File "C:\Users\4545\anaconda3\lib\site-packages\pip\_vendor\rich\console.py", line 1999, in _check_buffer
#     legacy_windows_render(
#   File "C:\Users\4545\anaconda3\lib\site-packages\pip\_vendor\rich\_windows_renderer.py", line 19, in legacy_windows_render
#     term.write_text(text)
#   File "C:\Users\4545\anaconda3\lib\site-packages\pip\_vendor\rich\_win32_console.py", line 403, in write_text
#     self.write(text)
# UnicodeEncodeError: 'cp949' codec can't encode character '\U0001f680' in position 26: illegal multibyte sequence
# Call stack:
#   File "C:\Users\4545\anaconda3\Scripts\pip-script.py", line 10, in <module>
#     sys.exit(main())
#   File "C:\Users\4545\anaconda3\lib\site-packages\pip\_internal\cli\main.py", line 70, in main
#     return command.main(cmd_args)
#   File "C:\Users\4545\anaconda3\lib\site-packages\pip\_internal\cli\base_command.py", line 101, in main
#     return self._main(args)
#   File "C:\Users\4545\anaconda3\lib\site-packages\pip\_internal\cli\base_command.py", line 214, in _main
#     return run(options, args)
#   File "C:\Users\4545\anaconda3\lib\site-packages\pip\_internal\cli\base_command.py", line 160, in exc_logging_wrapper
#     status = run_func(*args)
#   File "C:\Users\4545\anaconda3\lib\site-packages\pip\_internal\commands\show.py", line 45, in run
#     if not print_results(
#   File "C:\Users\4545\anaconda3\lib\site-packages\pip\_internal\commands\show.py", line 162, in print_results
#     write_output("Required-by: %s", ", ".join(dist.required_by))
#   File "C:\Users\4545\anaconda3\lib\site-packages\pip\_internal\utils\misc.py", line 336, in write_output
#     logger.info(msg, *args)
#   File "C:\Users\4545\anaconda3\lib\logging\__init__.py", line 1477, in info
#     self._log(INFO, msg, args, **kwargs)
#   File "C:\Users\4545\anaconda3\lib\logging\__init__.py", line 1624, in _log
#     self.handle(record)
#   File "C:\Users\4545\anaconda3\lib\logging\__init__.py", line 1634, in handle
#     self.callHandlers(record)
#   File "C:\Users\4545\anaconda3\lib\logging\__init__.py", line 1696, in callHandlers
#     hdlr.handle(record)
#   File "C:\Users\4545\anaconda3\lib\logging\__init__.py", line 968, in handle
#     self.emit(record)
#   File "C:\Users\4545\anaconda3\lib\site-packages\pip\_internal\utils\logging.py", line 179, in emit
#     self.handleError(record)
# Message: 'Required-by: %s'
# Arguments: ('',)

# %%
from ultralytics import YOLO
import cv2
import matplotlib.pyplot as plt
# Out:
# Creating new Ultralytics Settings v0.0.6 file
# View Ultralytics Settings with 'yolo settings' or at 'C:\Users\4545\AppData\Roaming\Ultralytics\settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %% [markdown]
# # 2. YOLO 인스턴스 생성하여 사물인식 처리

# %%
model = YOLO('yolov8n.pt')
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolov8n.pt to 'yolov8n.pt'...
# 100%|█████████████████████████████████████████████████████████████████████████████| 6.25M/6.25M [00:00<00:00, 18.7MB/s]

# %%
result = model.predict('data/mission_impossible_yolo.jpg')
# Out:
# image 1/1 D:\ai\source\09_\data\mission_impossible_yolo.jpg: 352x640 1 person, 9 cars, 6 motorcycles, 73.1ms
# Speed: 3.0ms preprocess, 73.1ms inference, 2.0ms postprocess per image at shape (1, 3, 352, 640)

# %%
result
# Out:
# [ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'person', 1: 'bicycle', 2: 'car', 3: 'motorcycle', 4: 'airplane', 5: 'bus', 6: 'train', 7: 'truck', 8: 'boat', 9: 'traffic light', 10: 'fire hydrant', 11: 'stop sign', 12: 'parking meter', 13: 'bench', 14: 'bird', 15: 'cat', 16: 'dog', 17: 'horse', 18: 'sheep', 19: 'cow', 20: 'elephant', 21: 'bear', 22: 'zebra', 23: 'giraffe', 24: 'backpack', 25: 'umbrella', 26: 'handbag', 27: 'tie', 28: 'suitcase', 29: 'frisbee', 30: 'skis', 31: 'snowboard', 32: 'sports ball', 33: 'kite', 34: 'baseball bat', 35: 'baseball glove', 36: 'skateboard', 37: 'surfboard', 38: 'tennis racket', 39: 'bottle', 40: 'wine glass', 41: 'cup', 42: 'fork', 43: 'knife', 44: 'spoon', 45: 'bowl', 46: 'banana', 47: 'apple', 48: 'sandwich', 49: 'orange', 50: 'broccoli', 51: 'carrot', 52: 'hot dog', 53: 'pizza', 54: 'donut', 55: 'cake', 56: 'chair', 57: 'couch', 58: 'potted plant', 59: 'bed', 60: 'dining table', 61: 'toilet', 62: 'tv', 63: 'laptop', 64: 'mouse', 65: 'remote', 66: 'keyboard', 67: 'cell phone', 68: 'microwave', 69: 'oven', 70: 'toaster', 71: 'sink', 72: 'refrigerator', 73: 'book', 74: 'clock', 75: 'vase', 76: 'scissors', 77: 'teddy bear', 78: 'hair drier', 79: 'toothbrush'}
#  obb: None
#  orig_img: array([[[107, 133, 147],
#          [107, 133, 147],
#          [107, 133, 147],
#          ...,
#          [ 65,  98,  77],
#          [ 67, 100,  79],
#          [ 64,  95,  74]],
#
#         [[113, 139, 153],
#          [113, 139, 153],
#          [113, 139, 153],
#          ...,
#          [ 64,  97,  76],
#          [ 66,  99,  78],
#          [ 64,  95,  74]],
#
#         [[124, 150, 164],
#          [125, 151, 165],
#          [125, 151, 165],
#          ...,
#          [ 64,  97,  76],
#          [ 67,  98,  77],
#          [ 69,  97,  77]],
#
#         ...,
#
#         [[180, 171, 161],
#          [180, 171, 161],
#          [180, 171, 161],
#          ...,
#          [161, 152, 142],
#          [163, 154, 144],
#          [161, 152, 142]],
#
#         [[180, 171, 161],
#          [180, 171, 161],
#          [180, 171, 161],
#          ...,
#          [163, 154, 144],
#          [165, 156, 146],
#          [165, 156, 146]],
#
#         [[180, 171, 161],
#          [180, 171, 161],
#          [180, 171, 161],
#          ...,
#          [167, 158, 148],
#          [169, 160, 150],
#          [169, 160, 150]]], dtype=uint8)
#  orig_shape: (480, 873)
#  path: 'D:\\ai\\source\\09_이미지처리\\data\\mission_impossible_yolo.jpg'
#  probs: None
#  save_dir: 'C:\\Users\\4545\\runs\\detect\\predict'
#  speed: {'preprocess': 2.991914749145508, 'inference': 73.13728332519531, 'postprocess': 1.9943714141845703}]

# %% [markdown]
# # 3.결과 시각화

# %%
result_image = result[0].plot() # BGR포맷

# %%
cv2.imwrite('data/mission_impossible_yoloresult.jpg', result_image)
# Out:
# True

# %%
plt.imshow(cv2.cvtColor(result_image, cv2.COLOR_BGR2RGB))
plt.show()
