# %%
import numpy as np
import pandas as pd
import requests
from urllib.request import urlopen
from bs4 import BeautifulSoup

# %% [markdown]
# - 순위, 책이름, 저자, 출판사, 가격

# %%
url = 'https://www.yes24.com/Product/Category/BestSeller?categoryNumber=001&pageNumber=1&pageSize=24'
response = requests.get(url)
soup = BeautifulSoup(response.text, "html.parser")
books = soup.select('div.info_name > a.gd_name')
author = soup.select('div.info_row span.info_auth')
publication = soup.select('div.info_pubGrp span.info_pub a')
price = soup.select('div.info_row strong')
data = []
for idx, (book, author, publication, price) in enumerate(zip(books, author, publication, price), 1):
    author_name = author.text.strip()
    author_name = author_name[:30] if len(author_name) > 30 else author_name    
    data.append({
        '순위': idx,
        '책 제목': book.text.strip(),
        '저자': author_name.strip(),
        '출판사': publication.text.strip(),
        '가격': price.text.strip()
    })
df_book = pd.DataFrame(data)
df_book
# Out:
#     순위                                      책 제목  \
# 0    1                                    소년이 온다
# 1    2                                     채식주의자
# 2    3                                  작별하지 않는다
# 3    4                   하루 한 장 나의 어휘력을 위한 필사 노트
# 4    5                            서랍에 저녁을 넣어 두었다
# 5    6                              트렌드 코리아 2025
# 6    7                                         흰
# 7    8                          산타 할아버지의 첫 크리스마스
# 8    9                                    희랍어 시간
# 9   10                                       넥서스
# 10  11                              어른의 행복은 조용하다
# 11  12                                트럼프 2.0 시대
# 12  13                        트럼프와 함께하는 알트코인 대폭등
# 13  14                                     일의 감각
# 14  15                                    해피버쓰데이
# 15  16  고전이 답했다 마땅히 살아야 할 삶에 대하여 (나만의 책 만들기 에디션)
# 16  17                    퓨처 셀프 30만 부 기념 스페셜 에디션
# 17  18                                       린치핀
# 18  19                                        모순
# 19  20                                 김미경의 딥마인드
# 20  21                            너에게 들려주는 단단한 말
# 21  22          ETS 토익 정기시험 기출문제집 1000 Vol. 4 RC
# 22  23                                  세이노의 가르침
# 23  24                        후 who? special 아이브
#
#                                 저자                        출판사       가격
# 0                             한강 저                         창비  13,500원
# 1                             한강 저                         창비  13,500원
# 2                             한강 저                       문학동네  15,120원
# 3                            유선경 저                     위즈덤하우스  21,420원
# 4                             한강 저                     문학과지성사  10,800원
# 5   김난도, 전미영, 최지혜, 권정윤, 한다혜 저 외 5명                       미래의창  18,000원
# 6                      한강 저/최진혁 사진                       문학동네  13,050원
# 7          맥 바넷 글/시드니 스미스 그림/김지은 역                       책읽는곰  13,500원
# 8                             한강 저                       문학동네  11,700원
# 9                   유발 하라리 저/김명주 역                        김영사  25,020원
# 10                            태수 저                     페이지2북스  16,020원
# 11                           박종훈 저                       글로퍼스  18,000원
# 12                           강환국 저                      거인의정원  24,300원
# 13                           조수용 저  레퍼런스 바이 비(REFERENCE by B)  19,800원
# 14                         백희나 글그림                      스토리보울  15,300원
# 15                           고명환 저                         라곰  15,120원
# 16                  벤저민 하디 저/최은아 역                      상상스퀘어  19,800원
# 17                   세스 고딘 저/윤영삼 역                         필름  21,420원
# 18                           양귀자 저                         쓰다  11,700원
# 19                           김미경 저                     어웨이크북스  16,200원
# 20                           김종원 저                      퍼스트펭귄  16,200원
# 21                           ETS 저                  YBM(와이비엠)  17,820원
# 22                    세이노(SayNo) 저                        데이원   6,480원
# 23                    조약돌 글/백재이 그림                      다산어린이  13,500원

# %%
url = 'https://www.yes24.com/Product/Category/BestSeller?categoryNumber=001&pageNumber=1&pageSize=24'
response = requests.get(url)
soup = BeautifulSoup(response.text, "html.parser")
rank = soup.select('div.img_upper > em')
books = soup.select('div.info_name > a.gd_name')
author = soup.select('div.info_row span.info_auth')
publication = soup.select('div.info_pubGrp span.info_pub a')
price = soup.select('div.info_row strong')
data = []
for idx, (rank, book, author, publication, price) in enumerate(zip(rank, books, author, publication, price), 1):
    author_name = author.text.strip()
    author_name = author_name.split('\r\n')[0].strip()    
    data.append({
        '순위': rank.text.strip(),
        '책 제목': book.text.strip(),
        '저자': author_name,
        '출판사': publication.text.strip(),
        '가격': price.text.strip()
    })
df_book = pd.DataFrame(data)
df_book.head(20)
# Out:
#     순위                                      책 제목  \
# 0    1                                    소년이 온다
# 1    2                                     채식주의자
# 2    3                                  작별하지 않는다
# 3    4                   하루 한 장 나의 어휘력을 위한 필사 노트
# 4    5                            서랍에 저녁을 넣어 두었다
# 5    6                              트렌드 코리아 2025
# 6    7                                         흰
# 7    8                          산타 할아버지의 첫 크리스마스
# 8    9                                    희랍어 시간
# 9   10                                       넥서스
# 10  11                              어른의 행복은 조용하다
# 11  12                                트럼프 2.0 시대
# 12  13                        트럼프와 함께하는 알트코인 대폭등
# 13  14                                     일의 감각
# 14  15                                    해피버쓰데이
# 15  16  고전이 답했다 마땅히 살아야 할 삶에 대하여 (나만의 책 만들기 에디션)
# 16  17                    퓨처 셀프 30만 부 기념 스페셜 에디션
# 17  18                                       린치핀
# 18  19                                        모순
# 19  20                                 김미경의 딥마인드
#
#                                 저자                        출판사       가격
# 0                             한강 저                         창비  13,500원
# 1                             한강 저                         창비  13,500원
# 2                             한강 저                       문학동네  15,120원
# 3                            유선경 저                     위즈덤하우스  21,420원
# 4                             한강 저                     문학과지성사  10,800원
# 5   김난도, 전미영, 최지혜, 권정윤, 한다혜 저 외 5명                       미래의창  18,000원
# 6                      한강 저/최진혁 사진                       문학동네  13,050원
# 7          맥 바넷 글/시드니 스미스 그림/김지은 역                       책읽는곰  13,500원
# 8                             한강 저                       문학동네  11,700원
# 9                   유발 하라리 저/김명주 역                        김영사  25,020원
# 10                            태수 저                     페이지2북스  16,020원
# 11                           박종훈 저                       글로퍼스  18,000원
# 12                           강환국 저                      거인의정원  24,300원
# 13                           조수용 저  레퍼런스 바이 비(REFERENCE by B)  19,800원
# 14                         백희나 글그림                      스토리보울  15,300원
# 15                           고명환 저                         라곰  15,120원
# 16                  벤저민 하디 저/최은아 역                      상상스퀘어  19,800원
# 17                   세스 고딘 저/윤영삼 역                         필름  21,420원
# 18                           양귀자 저                         쓰다  11,700원
# 19                           김미경 저                     어웨이크북스  16,200원

# %%
df_book.to_csv(r'D:\ai\Downloads\shareData\yes24.csv', index=False, encoding='cp949')
